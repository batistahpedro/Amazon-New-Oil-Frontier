# %% [markdown]
# <a href="https://colab.research.google.com/github/batistahpedro/Amazon-New-Oil-Frontier/blob/main/Amazon_New_Oil_Frontier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
import folium

# %%
import ee
ee.Authenticate()
ee.Initialize(project='ee-batistahpedro')

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Spatial Analysis ##

# %% [markdown]
# Shapefiles

# %%
import geopandas as gpd

base_path = "/content/drive/MyDrive/Amazon-New-Oil-Frontier/shapefiles"

# Polygons of major sedimentary basins across Brazil
sedimentary_basins = gpd.read_file(f"{base_path}/sedimentary_basins/bacias_gishub_db.shp")

# Extent of Brazilian coastal and marine ecological systems
coastal_marine_systems = gpd.read_file(f"{base_path}/coastal_marine_systems/Sistema_Costeiro_Marinho.shp")

# Priority areas for conservation in coastal and marine zones (2nd update)
priority_areas_zcm = gpd.read_file(f"{base_path}/priority_areas_zcm/ZCM_2a_atualizacao.shp")

# Priority areas for biodiversity conservation in the Amazon biome (2nd update)
priority_areas_amazon = gpd.read_file(f"{base_path}/priority_areas_amazon/Amazonia_2a_atualizacao.shp")

# Priority conservation areas in the Cerrado and Pantanal biomes (2nd update)
priority_areas_cerrado_pantanal = gpd.read_file(f"{base_path}/priority_areas_cerrado_pantanal/Cerrado_Pantanal_2a_atualizacao.shp")

# Priority conservation areas in the Caatinga biome (2nd update)
priority_areas_caatinga = gpd.read_file(f"{base_path}/priority_areas_caatinga/Caatinga_2a_atualizacao.shp")

# Oil and gas blocks to be offered in the 5th exploration cycle
offered_blocks = gpd.read_file(f"{base_path}/offered_blocks_cycle5/opc_blocos_em_oferta.shp")

# Oil and gas exploration blocks already under contract or licensed
exploration_blocks = gpd.read_file(f"{base_path}/exploration_blocks/block_shp_geoanp.shp")

# Hybrid zones in the Amazon with overlapping conservation and production designations (2nd update)
amazon_hybrid_zones = gpd.read_file(f"{base_path}/amazon_hybrid_zones/Areas_hibridas_2a_atualizacao.shp")

# %%
# List of all geodataframes to check
gdf_list = [
    ("sedimentary_basins", sedimentary_basins),
    ("coastal_marine_systems", coastal_marine_systems),
    ("priority_areas_zcm", priority_areas_zcm),
    ("priority_areas_amazon", priority_areas_amazon),
    ("priority_areas_cerrado_pantanal", priority_areas_cerrado_pantanal),
    ("priority_areas_caatinga", priority_areas_caatinga),
    ("offered_blocks", offered_blocks),
    ("exploration_blocks", exploration_blocks),
    ("amazon_hybrid_zones", amazon_hybrid_zones)
]

# Loop through each and print basic diagnostics
for name, gdf in gdf_list:
    print(f"\n🔎 Checking: {name}")
    print(f"  - Total features: {len(gdf)}")

    # Check CRS
    if gdf.crs:
        print(f"  - CRS: {gdf.crs}")
    else:
        print("  ⚠️ CRS is undefined!")

    # Null or empty geometry
    null_geom = gdf['geometry'].isna().sum()
    empty_geom = gdf['geometry'].is_empty.sum()
    print(f"  - Null geometries: {null_geom}")
    print(f"  - Empty geometries: {empty_geom}")

    # Invalid geometries
    invalid_geom = (~gdf.is_valid).sum()
    print(f"  - Invalid geometries: {invalid_geom}")

    # Columns available
    print(f"  - Columns: {list(gdf.columns)}")
# Out:
# 🔎 Checking: sedimentary_basins
#   - Total features: 72
#   - CRS: EPSG:4326
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 7
#   - Columns: ['feicao_id', 'situacao', 'objectid', 'name', 'code', 'creation_d', 'modificati', 'camada_id', 'geometry']
#
# 🔎 Checking: coastal_marine_systems
#   - Total features: 1
#   - CRS: EPSG:4674
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 1
#   - Columns: ['S_COSTEIRO', 'geometry']
#
# 🔎 Checking: priority_areas_zcm
#   - Total features: 114
#   - CRS: EPSG:4674
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 2
#   - Columns: ['OBJECTID', 'NOME_AP', 'IMP', 'PRIO', 'AcPrinc', 'Ac2', 'Ac3', 'AcPrincNom', 'Area_ha', 'N', 'ID_AP', 'AcPrincDet', 'Ac2Det', 'Ac3Det', 'TemaAcPrin', 'Shape_Leng', 'AcaoPrinc', 'Acao2', 'Acao3', 'geometry']
#
# 🔎 Checking: priority_areas_amazon
#   - Total features: 860
#   - CRS: EPSG:4674
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 19
#   - Columns: ['OBJECTID_1', 'OBJECTID', 'Nome_area', 'COD_area', 'Import_bio', 'Prior_acao', 'Acao_princ', 'Area_ha', 'Acao_Prin', 'Acao_2', 'Acao_3', 'Shape_Leng', 'Shape_Le_1', 'Shape_Area', 'geometry']
#
# 🔎 Checking: priority_areas_cerrado_pantanal
#   - Total features: 294
#   - CRS: EPSG:4674
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 2
#   - Columns: ['NOME', 'COD_area', 'Import_bio', 'Prior_acao', 'Area_ha', 'Estados', 'Shape_Leng', 'Shape_Area', 'Acao2', 'Acao1', 'Acao3', 'Acao4', 'geometry']
#
# 🔎 Checking: priority_areas_caatinga
#   - Total features: 275
#   - CRS: EPSG:4674
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 2
#   - Columns: ['OBJECTID_1', 'OBJECTID', 'Nome_area', 'COD_area', 'Import_bio', 'Prior_acao', 'Acao_princ', 'Area_ha', 'Shape_Leng', 'Shape_Area', 'geometry']
#
# 🔎 Checking: offered_blocks
#   - Total features: 332
#   - CRS: EPSG:4674
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 1
#   - Columns: ['nome_bacia', 'nomenclatu', 'situacao_b', 'nome_setor', 'indice_blo', 'area', 'AreaANP', 'geometry']
#
# 🔎 Checking: exploration_blocks
#   - Total features: 422
#   - CRS: EPSG:4674
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 0
#   - Columns: ['COD_BLOCO', 'COD_FASE_C', 'DAT_ASSINA', 'DAT_TERMIN', 'NOM_BACIA', 'NOM_BLOCO', 'NOM_FANTAS', 'NUM_CONTRA', 'NUM_DESCOB', 'OPERADOR_C', 'RODADA', 'AREA_TOTAL', 'AMBIENTE', 'BLOCOS', 'geometry']
#
# 🔎 Checking: amazon_hybrid_zones
#   - Total features: 163
#   - CRS: EPSG:4674
#   - Null geometries: 0
#   - Empty geometries: 0
#   - Invalid geometries: 12
#   - Columns: ['OBJECTID_1', 'OBJECTID_2', 'IB_pos', 'PA_pos', 'AçãoP_p', 'COD_area', 'Area_ha', 'Shape_Leng', 'Shape_Area', 'geometry']

# %%
# ================================================================
# Standardize CRS and fix invalid geometries
# ================================================================
# Ensure all layers use EPSG:4326 and have valid geometries for spatial operations

def fix_geodataframe(gdf, name):
    print(f"\nFixing: {name}")

    if gdf.crs is None or gdf.crs.to_epsg() != 4326:
        print("  - Reprojecting to EPSG:4326")
        gdf = gdf.to_crs(epsg=4326)

    invalid_count = (~gdf.is_valid).sum()
    if invalid_count > 0:
        print(f"  - Repairing {invalid_count} invalid geometries")
        gdf['geometry'] = gdf['geometry'].buffer(0)

    return gdf

coastal_marine_systems = fix_geodataframe(coastal_marine_systems, "coastal_marine_systems")
priority_areas_zcm = fix_geodataframe(priority_areas_zcm, "priority_areas_zcm")
priority_areas_amazon = fix_geodataframe(priority_areas_amazon, "priority_areas_amazon")
priority_areas_cerrado_pantanal = fix_geodataframe(priority_areas_cerrado_pantanal, "priority_areas_cerrado_pantanal")
priority_areas_caatinga = fix_geodataframe(priority_areas_caatinga, "priority_areas_caatinga")
offered_blocks = fix_geodataframe(offered_blocks, "offered_blocks")
sedimentary_basins = fix_geodataframe(sedimentary_basins, "sedimentary_basins")
amazon_hybrid_zones = fix_geodataframe(amazon_hybrid_zones, "amazon_hybrid_zones")
# Out:
# Fixing: coastal_marine_systems
#   - Reprojecting to EPSG:4326
#   - Repairing 1 invalid geometries
#
# Fixing: priority_areas_zcm
#   - Reprojecting to EPSG:4326
#   - Repairing 2 invalid geometries
#
# Fixing: priority_areas_amazon
#   - Reprojecting to EPSG:4326
#   - Repairing 19 invalid geometries
#
# Fixing: priority_areas_cerrado_pantanal
#   - Reprojecting to EPSG:4326
#   - Repairing 2 invalid geometries
#
# Fixing: priority_areas_caatinga
#   - Reprojecting to EPSG:4326
#   - Repairing 2 invalid geometries
#
# Fixing: offered_blocks
#   - Reprojecting to EPSG:4326
#   - Repairing 1 invalid geometries
#
# Fixing: sedimentary_basins
#   - Repairing 7 invalid geometries
#
# Fixing: amazon_hybrid_zones
#   - Reprojecting to EPSG:4326
#   - Repairing 12 invalid geometries

# %% [markdown]
# Port + Airport

# %%
port = gpd.GeoDataFrame(
    {
        'name_display': ['Porto de Belém'],
        'name_clean': ['porto_belem'],
        'type': ['port']
    },
    geometry=[Point(-48.49777700, -1,44527800)],
    crs='EPSG:4326'
)

airport = gpd.GeoDataFrame(
    {
        'name_display': ['Aeroporto de Oiapoque'],
        'name_clean': ['aeroporto_oiapoque'],
        'type': ['airport']
    },
    geometry=[Point(-51.79611100, 3.86138900)],
    crs='EPSG:4326'
)

# %%
import folium

# Ensure all datetime columns are converted to string
def sanitize_for_folium(gdf):
    for col in gdf.select_dtypes(include=["datetime64[ns]"]).columns:
        gdf[col] = gdf[col].astype(str)
    return gdf

# Sanitize each GeoDataFrame
sedimentary_basins = sanitize_for_folium(sedimentary_basins)
coastal_marine_systems = sanitize_for_folium(coastal_marine_systems)
priority_areas_amazon = sanitize_for_folium(priority_areas_amazon)
priority_areas_cerrado_pantanal = sanitize_for_folium(priority_areas_cerrado_pantanal)
priority_areas_caatinga = sanitize_for_folium(priority_areas_caatinga)
priority_areas_zcm = sanitize_for_folium(priority_areas_zcm)
offered_blocks = sanitize_for_folium(offered_blocks)
exploration_blocks = sanitize_for_folium(exploration_blocks)
amazon_hybrid_zones = sanitize_for_folium(amazon_hybrid_zones)

# Create base map
m = folium.Map(location=[-10, -55], zoom_start=4, tiles="CartoDB Positron")

# Style helper
def style(color):
    return lambda feature: {
        'color': color,
        'weight': 1,
        'fillOpacity': 0.3
    }

# Add layers as FeatureGroups
layers = [
    ("Sedimentary Basins", sedimentary_basins, "darkred"),
    ("Coastal & Marine Systems", coastal_marine_systems, "darkblue"),
    ("Amazon Priority Areas", priority_areas_amazon, "green"),
    ("Cerrado/Pantanal Priority Areas", priority_areas_cerrado_pantanal, "orange"),
    ("Caatinga Priority Areas", priority_areas_caatinga, "purple"),
    ("ZCM Priority Areas", priority_areas_zcm, "cadetblue"),
    ("Amazon Hybrid Zones", amazon_hybrid_zones, "gray"),
    ("Offered Blocks (5th cycle)", offered_blocks, "black"),
    ("Exploration Blocks", exploration_blocks, "red")
]

for name, gdf, color in layers:
    fg = folium.FeatureGroup(name=name, show=True)
    folium.GeoJson(gdf, style_function=style(color)).add_to(fg)
    fg.add_to(m)

# Add port and airport as separate interactive layers
fg_port = folium.FeatureGroup(name="Port of Belém", show=True)
folium.GeoJson(port, style_function=style("blue")).add_to(fg_port)
fg_port.add_to(m)

fg_airport = folium.FeatureGroup(name="Oiapoque Airport", show=True)
folium.GeoJson(airport, style_function=style("green")).add_to(fg_airport)
fg_airport.add_to(m)

# Add interactive layer control
folium.LayerControl(collapsed=False).add_to(m)

# Display map
m

# %% [markdown]
# Priority Areas

# %%
priority_areas = {
    "Amazon": priority_areas_amazon,
    "Cerrado_Pantanal": priority_areas_cerrado_pantanal,
    "Caatinga": priority_areas_caatinga,
    "ZCM": priority_areas_zcm,
    "Hybrid": amazon_hybrid_zones  # newly added
}

for name, gdf in priority_areas.items():
    print(f"\n{name} Priority Areas")
    print(f"- Total features: {len(gdf)}")
    print(f"- Columns: {list(gdf.columns)}")

    # Identify possible columns containing priority classification
    for col in gdf.columns:
        if gdf[col].dtype == 'object':
            unique_vals = gdf[col].dropna().unique()
            if any(keyword in str(unique_vals).lower() for keyword in ["alta", "prior", "prio", "import"]):
                print(f"  Possible priority column: '{col}' → Unique values: {list(unique_vals)}")
# Out:
# Amazon Priority Areas
# - Total features: 860
# - Columns: ['OBJECTID_1', 'OBJECTID', 'Nome_area', 'COD_area', 'Import_bio', 'Prior_acao', 'Acao_princ', 'Area_ha', 'Acao_Prin', 'Acao_2', 'Acao_3', 'Shape_Leng', 'Shape_Le_1', 'Shape_Area', 'geometry']
#   Possible priority column: 'Import_bio' → Unique values: ['Extremamente Alta', 'Alta', 'Muito Alta']
#   Possible priority column: 'Prior_acao' → Unique values: ['Extremamente alta', 'Alta', 'Muito alta']
#   Possible priority column: 'Acao_Prin' → Unique values: ['Desenvolvimento de turismo de base comunitária sustentável: Adoção de estratégias metodológicas que envolvam comunidades tradicionais para desenvolvimento de turismo de base comunitária', 'Fiscalização e controle de atividades ilegais', 'Criação de UC de Uso Sustentável', 'Recuperação de áreas degradadas', 'Recuperação de áreas degradadas: Melhoria do manejo do solo, água, pastagem', 'Recuperação de áreas degradadas: Restabelecimento de serviços ecossistêmicos (instrumentos de gestão do território - ZEE, planos diretores, etc.)', 'Recuperação de áreas degradadas: Manutenção de serviços ecossistêmicos (identificar prioridades)', 'Criação de instrumentos de governança (de bacias, reserva da biosfera, sítios Ramsar, etc.): Comitês de bacia', 'Pesquisa', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de políticas públicas', 'Reconhecimento de Território Quilombola (Regularização fundiária)', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade', 'Monitoramento e Manejo: Madeira empresarial', 'Monitoramento e Manejo: Produtos florestais não-madeireiros', 'Monitoramento e Manejo: Espécies envolvidas das cadeias de valor da sociobiodiversidade; Biodiversidade', 'Gestão integrada e participativa de áreas protegidas, corredores ecológicos e territórios de povos e comunidades tradicionais: Corredor ecológico (de acordo com o SNUC)', 'Criação de UC sem categoria definida', 'Reconhecimento/ Proteção de formação geológicas relevantes: Cavernas', 'Criação de UC de Proteção Integral', 'Limitação de atividade degradante', 'Reconhecimento de TI', 'Ampliação de UC', 'Fortalecimento dos instrumentos de gestão', 'Reconhecimento/ Proteção de formação geológicas relevantes: Geoparques; Cavernas', 'Gestão integrada e participativa de áreas protegidas, corredores ecológicos e territórios de povos e comunidades tradicionais', 'Criação de instrumentos de governança (de bacias, reserva da biosfera, sítios Ramsar, etc.)', 'Regularização de atividade degradante: Regularização ambiental ( CAR e PRA)', 'Regularização de atividade degradante: Extração de recursos minerais e florestais, desmatamento, queimadas, caça e pesca', 'Regularização de atividade degradante', 'Reconhecimento de áreas conservadas por comunidades tradicionais', 'Pesquisa: Habitat Crítico; Recurso Pesqueiro', 'Monitoramento e Manejo: Recurso pesqueiro; Madeira Empresarial', 'Monitoramento e Manejo: Recurso pesqueiro', 'Monitoramento e Manejo: Monitoramento de serviços ecossistêmicos', 'Regularização de atividade degradante: Extração de recursos minerais e florestais, desmatamento, queimadas, caça e pesca; Regularização ambiental (CAR e PRA)', 'Reconhecimento/ Proteção de formação geológicas relevantes', 'Criação de instrumentos de governança (de bacias, reserva da biosfera, sítios Ramsar, etc.): Acordos de pesca', 'Pesquisa:  Diagnóstico das cadeias de valor da sociobiodiversidade', 'Monitoramento e Manejo', 'Monitoramento e Manejo: Recurso pesqueiro; Monitoramento de espécies', 'Criação de instrumentos de governança (de bacias, reserva da biosfera, sítios Ramsar, etc.): Acordo de pesca', 'Pesquisa: Diagnóstico inicial de recursos', 'Criação de UC de Uso Sustentável: Criação de RESEX', 'Reconhecimento/ Proteção de formação geológicas relevantes: Geoparques', 'Pesquisa: Recurso Pesqueiro', 'Monitoramento e Manejo: Espécies envolvidas das cadeias de valor da sociobiodiversidade; Recursos faunísticos para fins de subsistência', 'Recuperação de áreas degradadas: Restabelecimento de serviços ecossistêmicos (instrumentos de gestão do território - ZEE, planos diretores, etc.); Manutenção de serviços ecossistêmicos (identificar prioridades)', 'Monitoramento e Manejo: Recurso pesqueiro; Madeira Empresarial; Madeira Comunitária', 'Monitoramento e Manejo: Recurso Pesqueiro', 'Monitoramento e Manejo: Madeira Comunitária; Produtos Florestais não madeireiros', 'Monitoramento e Manejo: Rec ...
#   Possible priority column: 'Acao_2' → Unique values: ['Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Análise de mercado', 'Recuperação de áreas degradadas', 'Recuperação de áreas degradadas: Restabelecimento de serviços ecossistêmicos (instrumentos de gestão do território - ZEE, planos diretores, etc.)', 'Pesquisa: Reconhecimento e valorização do conhecimento tradicional associado', 'Pesquisa: Diagnóstico participativo; Recursos faunísticos para fins de subsistência', 'Pesquisa', 'Pesquisa: Levantamento e caracterização de Biodiversidade', 'Pesquisa: Levantamento de uso e ocupação por comunidades residentes', 'Pesquisa: Habitat crítico; Levantamento e caracterização de Biodiversidade; Monitoramento de espécies', 'Pesquisa: Diagnóstico inicial de recursos', 'Pesquisa: Diagnóstico participativo; Reconhecimento e valorização do conhecimento tradicional associado; Recursos faunísticos para fins de subsistência', 'Pesquisa: Diagnóstico participativo', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de políticas públicas', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade', 'Criação de UC de Uso Sustentável', 'Recuperação de áreas degradadas: Manutenção de serviços ecossistêmicos (identificar prioridades)', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de tecnologias sociais; Adequação de políticas públicas', 'Monitoramento e Manejo: Habitat crítico', 'Monitoramento e Manejo: Espécies envolvidas das cadeias de valor da sociobiodiversidade', 'Monitoramento e Manejo', 'Recuperação de áreas degradadas: Melhoria do manejo do solo, água, pastagem', 'Monitoramento e Manejo: Recurso pesqueiro', 'Monitoramento e Manejo: Madeira empresarial', 'Monitoramento e Manejo: Uso e ocupação por comunidades residentes', 'Criação de UC sem categoria definida', 'Recuperação de áreas degradadas: Restabelecimento de serviços ecossistêmicos (instrumentos de gestão do território - ZEE, planos diretores, etc.); Manutenção de serviços ecossistêmicos (identificar prioridades)', 'Criação de UC de Proteção Integral', 'Pesquisa: Recursos faunísticos para fins de subsistência', 'Fortalecimento dos instrumentos de gestão', 'Reconhecimento de TI', 'Pesquisa: Recurso pesqueiro', 'Pesquisa: Habitat crítico', 'Reconhecimento de áreas conservadas por comunidades tradicionais', 'Pesquisa: Diagnóstico inicial de recursos; Levantamento e caracterização de Biodiversidade', 'Pesquisa: Recurso pesqueiro; Monitoramento de serviços ecossistêmicos', 'Gestão integrada e participativa de áreas protegidas, corredores ecológicos e territórios de povos e comunidades tradicionais', 'Gestão integrada e participativa de áreas protegidas, corredores ecológicos e territórios de povos e comunidades tradicionais: Corredor ecológico (de acordo com o SNUC)', 'Pesquisa: Habitat crítico; Recurso pesqueiro', 'Criação de instrumentos de governança (de bacias, reserva da biosfera, sítios Ramsar, etc.)', 'Pesquisa: Habitat crítico; Diagnóstico inicial de recursos; Geodiversidade;', 'Criação de instrumentos de governança (de bacias, reserva da biosfera, sítios Ramsar, etc.): Comitês de bacia; Acordo de pesca', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de tecnologias sociais', 'Fiscalização e controle de atividades ilegais', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de tecnologias sociais; Adequação de políticas públicas; Análise de mercado', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de políticas públicas; Controle social de políticas de repartição de benefícios; Análise de mercado', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de tecnologias sociais; Adequação de políticas públicas; Controle social de políticas de repartição de benefícios', 'Monitoramento e Manejo: Reconhecimento e valorização do conhecimento tradi ...
#   Possible priority column: 'Acao_3' → Unique values: ['Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade', 'Monitoramento e Manejo: Espécies envolvidas das cadeias de valor da sociobiodiversidade; Produtos florestais não-madeireiros', 'Fiscalização e controle de atividades ilegais', 'Criação de UC de Uso Sustentável: Criação de RESEX', 'Recuperação de áreas degradadas', 'Pesquisa: Monitoramento de espécies', 'Monitoramento e Manejo: Produtos florestais não-madeireiros', 'Monitoramento e Manejo', 'Criação de UC sem categoria definida', 'Gestão integrada e participativa de áreas protegidas, corredores ecológicos e territórios de povos e comunidades tradicionais: Corredor ecológico (de acordo com o SNUC)', 'Regularização de atividade degradante', 'Regularização de atividade degradante: Extração de recursos minerais e florestais, desmatamento, queimadas, caça e pesca', 'Gestão integrada e participativa de áreas protegidas, corredores ecológicos e territórios de povos e comunidades tradicionais: Mosaico', 'Pesquisa', 'Pesquisa: Diagnóstico inicial de recursos; Habitat crítico', 'Monitoramento e Manejo: Recursos faunísticos para fins de subsistência', 'Reconhecimento de TI', 'Pesquisa: Levantamento e caracterização de Biodiversidade', 'Pesquisa: Diagnóstico inicial de recursos', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de tecnologias sociais; Adequação de políticas públicas', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: Adequação de políticas públicas', 'Reconhecimento de Território Quilombola (Regularização fundiária)', 'Regularização de atividade degradante: Regularização ambiental ( CAR e PRA)', 'Criação de instrumentos de governança (de bacias, reserva da biosfera, sítios Ramsar, etc.): Comitês de bacia', 'Pesquisa: Diagnóstico inicial de recursos; Diagnóstico participativo', 'Desenvolvimento de turismo de base comunitária sustentável: Adoção de estratégias metodológicas que envolvam comunidades tradicionais para desenvolvimento de turismo de base comunitária', 'Gestão integrada e participativa de áreas protegidas, corredores ecológicos e territórios de povos e comunidades tradicionais', 'Criação de instrumentos de governança (de bacias, reserva da biosfera, sítios Ramsar, etc.)', 'Pesquisa: Diagnóstico das cadeias de valor da sociobiodiversidade', 'Pesquisa: Diagnóstico participativo', 'Monitoramento e Manejo: Uso e ocupação por comunidades residentes', 'Monitoramento e Manejo: Monitoramento de espécies', 'Monitoramento e Manejo: Recurso pesqueiro; Habitat crítico', 'Desenvolvimento de turismo de base comunitária sustentável', 'Recuperação de áreas degradadas: Manutenção de serviços ecossistêmicos (identificar prioridades)', 'Recuperação de áreas degradadas: Restabelecimento de serviços ecossistêmicos (instrumentos de gestão do território - ZEE, planos diretores, etc.)', 'Monitoramento e Manejo: Recurso pesqueiro; Espécies envolvidas das cadeias de valor da sociobiodiversidade; Produtos florestais não-madeireiros', 'Monitoramento e Manejo: Espécies envolvidas das cadeias de valor da sociobiodiversidade; Madeira comunitária; Produtos florestais não-madeireiros', 'Desenvolvimento de turismo de base comunitária sustentável: Adoção de estratégias metodológicas que envolvam comunidades tradicionais para desenvolvimento de turismo de base comunitária; Turismo de baixo impacto', 'Desenvolvimento de turismo de base comunitária sustentável: Turismo de baixo impacto', 'Pesquisa: Habitat crítico; Recurso pesqueiro', 'Pesquisa: Diagnóstico inicial de recursos; Reconhecimento e valorização do conhecimento tradicional associado; Diagnóstico das cadeias de valor da sociobiodiversidade; Recurso pesqueiro', 'Pesquisa: Recurso pesqueiro', 'Pesquisa: Diagnóstico das cadeias de valor da sociobiodiversidade; Diagnóstico participativo; Recursos faunísticos para fins de subsistência', 'Fortalecimento das cadeias de valor dos produtos da sociobiodiversidade: ...
#
# Cerrado_Pantanal Priority Areas
# - Total features: 294
# - Columns: ['NOME', 'COD_area', 'Import_bio', 'Prior_acao', 'Area_ha', 'Estados', 'Shape_Leng', 'Shape_Area', 'Acao2', 'Acao1', 'Acao3', 'Acao4', 'geometry']
#   Possible priority column: 'NOME' → Unique values: ['Formosa do Rio Preto', 'Rio Sapão', 'Rio de Ondas', 'Correntina', 'Entorno RVS Veredas', 'Jaborandi', 'Riacho do Ramalho', 'Riacho Pedra-Branca', 'Muquem de São Francisco', 'Rio de Janeiro', 'São Desidério', 'Lagoas do Rio São Francisco', 'Iuiú', 'Rio Mutum', 'Rio Arrojado', 'Rio Formoso', 'Rio das Balsas', 'Entorno TI Kanela - TI Porquinhos', 'Rio Itapicuru', 'Rio Parnaiba - Balsas', 'Rio Sucuriiju', 'Lizarda', 'Recursolândia', 'Rio Sono', 'Rio do Sono', 'Rio Uruçui-Vermelho', 'Rio Ponte Alta', 'Rio Tocantins', 'Barreirinhas', 'Codó', 'Matões', 'Entorno TI Bacuruzinho', 'Entorno TI Kraolandia', 'Riacho Tucum', 'Rio Parnaiba II', 'Nascente Uruçui', 'Serra do Quilombo', 'Rio Galhão', 'Entorno ESEC Serra Geral do Tocantins', 'Ponte Alta', 'Porto Nacional', 'Rio do Fogo', 'Rio Santa Tereza', 'Rio São Valério', 'Córrego São Felipe', 'Rio Bagagem', 'Almas', 'Conceição do Tocantins', 'Serra de Caldas', 'Lajeado', 'Aurora do Tocantins', 'Lagoa do Tocantins', 'Entorno TI Xerente', 'Entorno PN Nascentes do Parnaíba', 'Entorno PN Serra das Confusões I', 'Riozinho', 'Rio da Meia Ponte', 'Rio Piracanjuba', 'Rio São Bartolomeu', 'Santa Cruz de Goiás', 'Pirenópolis', 'Rio Corumbá', 'Rio São Marcos', 'Entorno PE Serra Dourada', 'Jacuba - Corrente', 'Rio da Prata', 'Rio dos Bois', 'Rio Turvo - GO', 'Rio Ponte de Pedra', 'Rio do Cervo', 'Formosa', 'Serra de São Bartolomeu', 'Entorno PN Chapada dos Veadeiros', 'Rio Cristalino', 'Araguaaçu', 'Pouso Alto', 'Rio Paranã', 'Niquelândia', 'Mambaí', 'Serra da Prata', 'Rio Corrente', 'Rio Cana Brava', 'Chapada da Contagem', 'Rio Maranhão', 'Uruaçu', 'Rio Traíras', 'Crixás', 'Rio Araguaia II', 'Ribeirão Barreiro', 'Barra do Garças', 'Piranhas', 'Caiapônia', 'Rio Caiapó', 'Doverlândia', 'Jataí', 'Rio Doce', 'Serranópolis', 'Alto Araguaia', 'Coribe', 'São Felix do Coribe', 'Baianópolis', 'Cristópolis', 'Cotegipe', 'Santa Maria da Vitória', 'São Domingos', 'Cristalina', 'Entorno TI Areões I', 'Entorno TI Areões II', 'Entorno TI Areões III', 'Nova Xavantina', 'Rio Arinos', 'Entorno TI Merure', 'Rio Pindaíba', 'Entorno TI Sangradouro / Volta Grande', 'Rio Formiga', 'Rio Jaguara', 'Rio Cuiabá', 'Rio Manso', 'Rio dos Cavalos', 'Rio São Domingos', 'Três Lagoas', 'Alto Rio Taquari', 'Ribeirão Ponte de Pedra', 'Rio Itiquira - Pantanal', 'Córrego Pindaival', 'Rio São Lourenço', 'Ribeirão Mutum', 'Rio Aricá-Açu', 'Rio Cuiabá-Mirim', 'Rio Coxipó', 'Rio Piraim', 'Vazante Santa Maria', 'Rio Paraguai - Corumbá', 'Rio Taquari', 'Vazante Riozinho', 'Vazante Grande', 'Rio Negro', 'Rio Negro - Serra Maracaju', 'Rio Taboco', 'Córrego Agachi', 'Corumbá', 'Rio Miranda', 'Rio Nabileque', 'Rio Aquidabã', 'Rio Perdido', 'Rio Caracol', 'Bonito', 'Rio Miranda - Pantanal', 'Rio Feio', 'Rio Itiquira', 'Rio Tarumã', 'Nioaque', 'Rio Apa', 'Córrego Itá', 'Bela Vista', 'Rio Lajeado - MS', 'Córrego Belchior', 'Ribeirão Aquidauana', 'Corixo do Guirá', 'Rio Areial', 'Rio Prata', 'Ribeirão Serrote', 'Rio do Peixe', 'Córrego Fundo', 'Rio Coxim', 'Rio Jauru -MS', 'Rio Verde', 'Ribeirão Cachoeira', 'Nascentes do Rio Paraguai', 'Bodoquena', 'Rio Correntes', 'Rio Sapucaí', 'Rio Turvo - SP', 'Rio Preto', 'São José dos Dourados', 'Itirapina', 'Rio Jacaré-Pepira', 'Pedregulho', 'Itapetininga', 'Itararé', 'Pandeiros Conchá e Gibão', 'Jaiba', 'Ribeirão Ticororó', 'Serra do Cabral', 'Rio Paracatu 2', 'São Romão', 'Unaí', 'Santuario São Miguel', 'Bonfinópolis', 'Jequitaí', 'Rio Paraopeba', 'Felixlândia', 'Corinto', 'Curvelo', 'Rio Borrachudo', 'Ibiá', 'Rio das Velhas', 'Unaí II', 'São Pedro', 'Rio Paracatu', 'Buritizeiro', 'São Bartolomeu', 'Riacho do Bano', 'Divinópolis', 'Presidente Olegário', 'Vazante', 'Rio das Tabocas', 'Araxá', 'Tapira', 'Alpinópolis', 'Furnas', 'Cristais', 'Riacho dos Machados', 'João Pinheiro', 'Foz do Carinhanha', 'Campos Gerais', 'Cocos', 'Rio Urucuia', 'Sacramento', 'Diamantina', 'Carste Arcos e Pains', 'Carinhana', 'Formoso', 'Peruacu', 'Cavernas peruacu', 'Cavernas de U ...
#   Possible priority column: 'Import_bio' → Unique values: ['Muito Alta', 'Extremamente Alta', 'Alta', 'Muita Alta']
#   Possible priority column: 'Prior_acao' → Unique values: ['Extremamente Alta', 'Muito Alta', 'Alta', 'Muito alta', 'Muita Alta']
#
# Caatinga Priority Areas
# - Total features: 275
# - Columns: ['OBJECTID_1', 'OBJECTID', 'Nome_area', 'COD_area', 'Import_bio', 'Prior_acao', 'Acao_princ', 'Area_ha', 'Shape_Leng', 'Shape_Area', 'geometry']
#   Possible priority column: 'Import_bio' → Unique values: ['Muito Alta', 'Alta', 'Extremamente Alta']
#   Possible priority column: 'Prior_acao' → Unique values: ['Muito Alta', 'Extremamente Alta', 'Alta']
#
# ZCM Priority Areas
# - Total features: 114
# - Columns: ['OBJECTID', 'NOME_AP', 'IMP', 'PRIO', 'AcPrinc', 'Ac2', 'Ac3', 'AcPrincNom', 'Area_ha', 'N', 'ID_AP', 'AcPrincDet', 'Ac2Det', 'Ac3Det', 'TemaAcPrin', 'Shape_Leng', 'AcaoPrinc', 'Acao2', 'Acao3', 'geometry']
#   Possible priority column: 'IMP' → Unique values: ['Alta', 'Muito Alta', 'Extremamente Alta', 'Insuficientemente conhecida']
#   Possible priority column: 'PRIO' → Unique values: ['Alta', 'Muito Alta', 'Extremamente Alta']
#
# Hybrid Priority Areas
# - Total features: 163
# - Columns: ['OBJECTID_1', 'OBJECTID_2', 'IB_pos', 'PA_pos', 'AçãoP_p', 'COD_area', 'Area_ha', 'Shape_Leng', 'Shape_Area', 'geometry']
#   Possible priority column: 'IB_pos' → Unique values: ['Extremamente alta', 'Muito Alta', 'Muito alta', 'Alta', 'Extremamente Alta', 'Extremamente Alta\r\nExtremamente alta']
#   Possible priority column: 'PA_pos' → Unique values: ['Extremamente alta', 'Alta', 'Muito alta', 'Muito Alta', 'Extremamente Alta']

# %%
import pandas as pd
import geopandas as gpd

# Define robust cleaning function
def clean_priority(value):
    if pd.isna(value):
        return None

    # Remove line breaks, tabs, extra spaces
    val = str(value).replace("\r", " ").replace("\n", " ").replace("\t", " ").strip()

    # If multiple values, take the first
    for sep in [";", ","]:
        if sep in val:
            val = val.split(sep)[0].strip()

    val = val.lower()

    if "extremamente" in val or "extremely" in val:
        return "Extremely High"
    elif "muito" in val or "very" in val:
        return "Very High"
    elif "alta" in val or "high" in val:
        return "High"
    else:
        return None

# Apply cleaning logic to each dataset individually
priority_areas_amazon["priority_level"] = priority_areas_amazon["Import_bio"].apply(clean_priority)
priority_areas_cerrado_pantanal["priority_level"] = priority_areas_cerrado_pantanal["Import_bio"].apply(clean_priority)
priority_areas_caatinga["priority_level"] = priority_areas_caatinga["Import_bio"].apply(clean_priority)
priority_areas_zcm["priority_level"] = priority_areas_zcm["IMP"].apply(clean_priority)

# Hybrid zones: choose appropriate source column
# Prefer 'Import_bio', fallback to 'IB_pos' if needed
if "Import_bio" in amazon_hybrid_zones.columns:
    source_col = "Import_bio"
elif "IB_pos" in amazon_hybrid_zones.columns:
    source_col = "IB_pos"
else:
    raise ValueError("No valid priority column found in hybrid zones.")

amazon_hybrid_zones["priority_level"] = amazon_hybrid_zones[source_col].apply(clean_priority)

# Confirm cleanup
for name, gdf in {
    "Amazon": priority_areas_amazon,
    "Cerrado_Pantanal": priority_areas_cerrado_pantanal,
    "Caatinga": priority_areas_caatinga,
    "ZCM": priority_areas_zcm,
    "Hybrid": amazon_hybrid_zones
}.items():
    print(f"{name} — unique priority values: {gdf['priority_level'].dropna().unique()}")
# Out:
# Amazon — unique priority values: ['Extremely High' 'High' 'Very High']
# Cerrado_Pantanal — unique priority values: ['Very High' 'Extremely High' 'High']
# Caatinga — unique priority values: ['Very High' 'High' 'Extremely High']
# ZCM — unique priority values: ['High' 'Very High' 'Extremely High']
# Hybrid — unique priority values: ['Extremely High' 'Very High' 'High']

# %%
import geopandas as gpd
import pandas as pd

# Concatenate all cleaned layers into a single GeoDataFrame
all_priority_areas = pd.concat(
    [
        priority_areas_amazon[["geometry", "priority_level"]],
        priority_areas_cerrado_pantanal[["geometry", "priority_level"]],
        priority_areas_caatinga[["geometry", "priority_level"]],
        priority_areas_zcm[["geometry", "priority_level"]],
        amazon_hybrid_zones[["geometry", "priority_level"]]
    ],
    ignore_index=True
)

# Keep only the priority levels of interest
all_priority_areas = all_priority_areas[
    all_priority_areas["priority_level"].isin(["Extremely High", "Very High", "High"])
].copy()

# Report
print(f"Total unified features: {len(all_priority_areas)}")
print("Priority levels included:", all_priority_areas["priority_level"].unique())
# Out:
# Total unified features: 1705
# Priority levels included: ['Extremely High' 'High' 'Very High']

# %% [markdown]
# ## Distance to priority areas ##

# %%
# List of all layers to inspect
layers = {
    "exploration_blocks": exploration_blocks,
    "offered_blocks": offered_blocks,
    "port": port,
    "airport": airport
}

# Print structure of each layer
for name, gdf in layers.items():
    print(f"\n📌 Layer: {name}")
    print("Columns:", list(gdf.columns))
    print("First few rows:")
    display(gdf.head(3))
# Out:
# 📌 Layer: exploration_blocks
# Columns: ['COD_BLOCO', 'COD_FASE_C', 'DAT_ASSINA', 'DAT_TERMIN', 'NOM_BACIA', 'NOM_BLOCO', 'NOM_FANTAS', 'NUM_CONTRA', 'NUM_DESCOB', 'OPERADOR_C', 'RODADA', 'AREA_TOTAL', 'AMBIENTE', 'BLOCOS', 'geometry']
# First few rows:
#     COD_BLOCO COD_FASE_C  DAT_ASSINA DAT_TERMIN NOM_BACIA   NOM_BLOCO  \
# 0  SO_DE_SGTR          E  31-05-2023       None    Santos  SO_DE_SGTR
# 1  BUMERANGUE          E  01-06-2023       None    Santos  BUMERANGUE
# 2  ÁGUA-MARIN          E  31-05-2023       None    Campos  ÁGUA-MARIN
#
#           NOM_FANTAS         NUM_CONTRA  NUM_DESCOB  \
# 0  SO_Sagitário_OPP1  48610232918202288         0.0
# 1    Bumerangue_OPP1  48610232917202233         0.0
# 2  Água_Marinha_OPP1  48610232915202244         0.0
#
#                              OPERADOR_C RODADA  AREA_TOTAL AMBIENTE BLOCOS  \
# 0  Petróleo Brasileiro S.A. - PETROBRAS   OPP1      1036.0        M   None
# 1             BP Energy do Brasil Ltda.   OPP1      1119.0        M   None
# 2  Petróleo Brasileiro S.A. - PETROBRAS   OPP1      1300.0        M   None
#
#                                             geometry
# 0  POLYGON ((-44.37544 -25.45833, -44.41927 -25.4...
# 1  POLYGON ((-43.53385 -26.5026, -43.53385 -26.49...
# 2  POLYGON ((-40.18529 -22.75311, -40.18269 -22.7...
# 📌 Layer: offered_blocks
# Columns: ['nome_bacia', 'nomenclatu', 'situacao_b', 'nome_setor', 'indice_blo', 'area', 'AreaANP', 'geometry']
# First few rows:
#   nome_bacia nomenclatu situacao_b nome_setor indice_blo     area  AreaANP  \
# 0     Santos   S-M-1283          M     SS-AR4       1283  172.673  172.673
# 1     Santos   S-M-1284          M     SS-AR4       1284  172.673  172.673
# 2     Santos    S-M-502          M     SS-AR3        502  174.987  174.987
#
#                                             geometry
# 0  POLYGON ((-47.125 -26.375, -47.125 -26.5, -47....
# 1  POLYGON ((-47 -26.375, -47 -26.5, -47.125 -26....
# 2  POLYGON ((-45.125 -24.75, -45.125 -24.875, -45...
# 📌 Layer: port
# Columns: ['name_display', 'name_clean', 'type', 'geometry']
# First few rows:
#      name_display   name_clean  type                         geometry
# 0  Porto de Belém  porto_belem  port  POINT Z (-48.49778 -1 44527800)
# 📌 Layer: airport
# Columns: ['name_display', 'name_clean', 'type', 'geometry']
# First few rows:
#             name_display          name_clean     type  \
# 0  Aeroporto de Oiapoque  aeroporto_oiapoque  airport
#
#                     geometry
# 0  POINT (-51.79611 3.86139)

# %%
import geopandas as gpd
import pandas as pd
import os

# Output directory
output_dir = "/content/drive/MyDrive/Amazon-New-Oil-Frontier/Results"
os.makedirs(output_dir, exist_ok=True)

# Reproject to EPSG:3857 for metric calculations
print("🔄 Reprojecting layers to EPSG:3857...")
priority_areas_3857 = all_priority_areas.to_crs(epsg=3857)
exploration_blocks = exploration_blocks.to_crs(epsg=3857)
offered_blocks = offered_blocks.to_crs(epsg=3857)
port = port.to_crs(epsg=3857)
airport = airport.to_crs(epsg=3857)
print("✅ Reprojection complete.")

# ID columns for identification
id_columns = {
    "exploration_blocks": "COD_BLOCO",
    "offered_blocks": "nomenclatu",
    "port": "Name",
    "airport": "Name"
}

# Function to compute diagnostics
def compute_and_report(gdf, name):
    print(f"\n🟩 Processing: {name}")
    id_col = id_columns.get(name)

    results = []
    for idx, row in gdf.iterrows():
        geom = row.geometry
        feature_id = row[id_col] if id_col in row else f"Feature {idx}"

        intersections = priority_areas_3857[priority_areas_3857.intersects(geom)]

        if not intersections.empty:
            priority_class = ", ".join(intersections["priority_level"].unique())
            intersection_area = intersections.intersection(geom).area.sum()
            pct = (intersection_area / geom.area) * 100 if geom.area > 0 else 0
            dist = 0

            print(f"  ✅ {feature_id} — Intersection found")
            print(f"     Bounds: {geom.bounds}")
            print(f"     Priority level(s): {priority_class}")
            print(f"     Overlap: {pct:.2f}%")
        else:
            priority_class = "No Priority Area"
            pct = 0
            dist = priority_areas_3857.geometry.distance(geom).min()

            print(f"  ❌ {feature_id} — No intersection")
            print(f"     Bounds: {geom.bounds}")
            print(f"     Min. distance to priority area: {dist:.2f} meters")

        results.append((priority_class, pct, dist))

    # Store results
    gdf["priority_class"] = [r[0] for r in results]
    gdf["overlap_pct_priority_area"] = [round(r[1], 2) for r in results]
    gdf["priority_dist"] = [round(r[2] / 1000, 2) for r in results]  # in kilometers
    return gdf

# Run diagnostics and update original GeoDataFrames explicitly
exploration_blocks = compute_and_report(exploration_blocks, "exploration_blocks")
offered_blocks = compute_and_report(offered_blocks, "offered_blocks")
port = compute_and_report(port, "port")
airport = compute_and_report(airport, "airport")

# Export all to Excel
print("\n📤 Exporting results to Excel (in kilometers)...")
exploration_blocks.to_crs(epsg=4326).drop(columns="geometry").to_excel(f"{output_dir}/exploration_blocks_diagnostics_km.xlsx", index=False)
offered_blocks.to_crs(epsg=4326).drop(columns="geometry").to_excel(f"{output_dir}/offered_blocks_diagnostics_km.xlsx", index=False)
port.to_crs(epsg=4326).drop(columns="geometry").to_excel(f"{output_dir}/port_diagnostics_km.xlsx", index=False)
airport.to_crs(epsg=4326).drop(columns="geometry").to_excel(f"{output_dir}/airport_diagnostics_km.xlsx", index=False)
print("✅ All diagnostics completed and exported.")
# Out:
# 🔄 Reprojecting layers to EPSG:3857...
# ✅ Reprojection complete.
#
# 🟩 Processing: exploration_blocks
#   ❌ SO_DE_SGTR — No intersection
#      Bounds: (-4944730.610575172, -2932208.7468948327, -4905063.805779096, -2886623.8977237814)
#      Min. distance to priority area: 8222.50 meters
#   ✅ BUMERANGUE — Intersection found
#      Bounds: (-4854283.524305637, -3094869.4614607133, -4806161.036098136, -3048837.056750045)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ ÁGUA-MARIN — Intersection found
#      Bounds: (-4487321.1482882425, -2628554.7760136146, -4431617.332699926, -2597159.270458525)
#      Priority level(s): Very High
#      Overlap: 7.77%
#   ❌ PN-T-102A — No intersection
#      Bounds: (-4953717.340300674, -669141.0570442461, -4898057.594904037, -613199.6633499706)
#      Min. distance to priority area: 27835.18 meters
#   ✅ ES-T-517 — Intersection found
#      Bounds: (-4431949.763868368, -2199136.228272881, -4424949.759032625, -2187826.687813247)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ✅ ES-T-466 — Intersection found
#      Bounds: (-4438864.695381784, -2174568.0755705643, -4431907.227207203, -2169658.1816495885)
#      Priority level(s): Extremely High
#      Overlap: 94.47%
#   ✅ ES-T-486A — Intersection found
#      Bounds: (-4438864.695381784, -2184448.662518601, -4436255.644816317, -2178922.2697488307)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ✅ ES-T-527 — Intersection found
#      Bounds: (-4438864.695381784, -2204053.6180698806, -4431907.227207203, -2199136.228272881)
#      Priority level(s): Extremely High
#      Overlap: 99.86%
#   ❌ REC-T-69 — No intersection
#      Bounds: (-4244094.976029763, -1350500.8183577124, -4237137.440023709, -1345758.4662610434)
#      Min. distance to priority area: 21090.99 meters
#   ❌ REC-T-107 — No intersection
#      Bounds: (-4258010.0603430085, -1369477.5572464673, -4251052.526590262, -1365325.3711720333)
#      Min. distance to priority area: 26275.78 meters
#   ❌ REC-T-79 — No intersection
#      Bounds: (-4244094.982112405, -1355243.8972064129, -4237137.446074258, -1350500.8093426274)
#      Min. distance to priority area: 25519.37 meters
#   ❌ BM-PAMA-3 — No intersection
#      Bounds: (-5134657.384184057, 111287.516459735, -5099869.768834453, 143762.47858000157)
#      Min. distance to priority area: 15227.95 meters
#   ❌ REC-T-88 — No intersection
#      Bounds: (-4244094.988217655, -1359987.7145276354, -4237137.452147359, -1355243.8881592122)
#      Min. distance to priority area: 30044.45 meters
#   ❌ C-M-789 — No intersection
#      Bounds: (-4560040.599422382, -2845068.856710045, -4536269.249825899, -2794715.4833507515)
#      Min. distance to priority area: 33436.54 meters
#   ❌ POT-M-855 — No intersection
#      Bounds: (-4091028.589370482, -501496.3640528873, -4063198.4576834394, -473584.88338708645)
#      Min. distance to priority area: 7304.32 meters
#   ✅ POT-M-853 — Intersection found
#      Bounds: (-4118858.7080613645, -501496.35123833717, -4091028.5770027307, -473584.87120684166)
#      Priority level(s): Extremely High
#      Overlap: 0.00%
#   ❌ REC-T-121 — No intersection
#      Bounds: (-4237137.476665644, -1374173.3093312215, -4230140.650144396, -1369427.301606193)
#      Min. distance to priority area: 16848.89 meters
#   ❌ REC-T-77 — No intersection
#      Bounds: (-4257970.522842714, -1355193.7475665896, -4251052.505938391, -1350450.7101266168)
#      Min. distance to priority area: 16355.57 meters
#   ❌ BAR-M-344 — No intersection
#      Bounds: (-4675460.8215983575, -222724.50141945612, -4647630.712688329, -194879.46549952342)
#      Min. distance to priority area: 48349.95 meters
#   ❌ BAR-M-346 — No intersection
#      Bounds: (-4647630.718644022, -222724.50783831818, -4619800.6089675585, -194879.47114659197)
#      Min. distance to priority area: 48003.25 meters
#   ❌ BAR-M-342 — No intersection
#      Bounds: (-4703290.923749089, -222724.49496522642, -4675460.8156099925, -194879.4598216194)
#      Min. distance to priority area: 55890.85 meters
#   ❌ BAR-M-340 — No intersection
#      Bounds: (-4731121.025091843, -222724.48847575486, -4703290.917728175, -194879.45411298698)
#      Min. distance to priority area: 73639.72 meters
#   ❌ POT-T-478 — No intersection
#      Bounds: (-4125778.627525702, -584417.0613869892, -4118821.159351122, -580589.1608694581)
#      Min. distance to priority area: 4452.78 meters
#   ✅ POT-T-476 — Intersection found
#      Bounds: (-4142630.307233743, -585290.4051036345, -4132736.095700281, -580589.1608694581)
#      Priority level(s): High
#      Overlap: 42.34%
#   ❌ POT-T-433 — No intersection
#      Bounds: (-4132736.095700281, -580589.1608694581, -4125778.627525702, -575931.7726758609)
#      Min. distance to priority area: 745.21 meters
#   ❌ POT-T-392 — No intersection
#      Bounds: (-4125816.2743991297, -575931.7726758609, -4118821.159351122, -571274.6907220128)
#      Min. distance to priority area: 5761.31 meters
#   ❌ POT-T-652 — No intersection
#      Bounds: (-4160565.9683986, -603880.7830908563, -4153608.5002240203, -599221.8261269907)
#      Min. distance to priority area: 1806.59 meters
#   ✅ POT-T-651 — Intersection found
#      Bounds: (-4167523.436573179, -603880.7830908563, -4160565.9683986, -599221.8261269907)
#      Priority level(s): Extremely High
#      Overlap: 14.08%
#   ❌ ES-T-345 — No intersection
#      Bounds: (-4431907.227207203, -2115730.35099991, -4424949.759032625, -2110835.101595291)
#      Min. distance to priority area: 735.64 meters
#   ✅ S-M-1719 — Intersection found
#      Bounds: (-5065036.831093947, -3186080.23336501, -5037206.958395629, -3154740.8166665663)
#      Priority level(s): High
#      Overlap: 100.00%
#   ❌ C-M-715 — No intersection
#      Bounds: (-4452779.631730943, -2783901.423375836, -4424949.759032625, -2753408.10936498)
#      Min. distance to priority area: 47936.17 meters
#   ✅ SOL-T-170 — Intersection found
#      Bounds: (-7347146.569046339, -557305.2572745768, -7330272.510934152, -529665.2153512976)
#      Priority level(s): High
#      Overlap: 41.34%
#   ✅ S-M-1717 — Intersection found
#      Bounds: (-5092866.703792266, -3186080.23336501, -5065036.831093947, -3154740.8166665663)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ S-M-1715 — Intersection found
#      Bounds: (-5120696.576490585, -3186080.23336501, -5092866.703792266, -3154740.8166665663)
#      Priority level(s): High, Very High
#      Overlap: 100.00%
#   ✅ S-M-1709 — Intersection found
#      Bounds: (-5204186.194585539, -3186080.23336501, -5176356.321887221, -3154740.8166665663)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ❌ REC-T-78 — No intersection
#      Bounds: (-4251052.512030563, -1355243.8881592122, -4244094.976029763, -1350500.8003133938)
#      Min. distance to priority area: 23135.39 meters
#   ❌ C-M-753 — No intersection
#      Bounds: (-4536269.249825899, -2814454.7323097703, -4508439.377127579, -2783901.423375836)
#      Min. distance to priority area: 43079.97 meters
#   ✅ POT-M-859 — Intersection found
#      Bounds: (-4035331.5412561675, -515412.6837392479, -4007501.6685578483, -473542.2854889546)
#      Priority level(s): Very High, Extremely High
#      Overlap: 3.66%
#   ❌ POT-M-762 — No intersection
#      Bounds: (-4118858.695612061, -473584.88338708645, -4090991.2866528034, -445640.10965602624)
#      Min. distance to priority area: 4553.44 meters
#   ✅ POT-M-948 — Intersection found
#      Bounds: (-4007501.6685578483, -510759.3554317195, -3979671.7958595306, -501453.5101383216)
#      Priority level(s): Extremely High
#      Overlap: 18.53%
#   ❌ C-M-61 — No intersection
#      Bounds: (-4452822.947317317, -2451658.523498971, -4441763.640454529, -2436709.208236156)
#      Min. distance to priority area: 10298.92 meters
#   ✅ ES-T-453 — Intersection found
#      Bounds: (-4438864.695381784, -2169715.13460382, -4431907.227207203, -2164749.5257403925)
#      Priority level(s): Extremely High
#      Overlap: 87.51%
#   ❌ PAMA-M-194 — No intersection
#      Bounds: (-5065082.156032464, 83454.1677694897, -5037252.061833962, 111287.52602936635)
#      Min. distance to priority area: 16037.81 meters
#   ✅ POT-T-740 — Intersection found
#      Bounds: (-4188434.059579345, -613199.6633499706, -4182018.161936883, -608540.061328945)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ❌ PAMA-M-265 — No intersection
#      Bounds: (-5037252.061833962, 55622.40451022177, -5009421.967654829, 83454.17295396837)
#      Min. distance to priority area: 8079.86 meters
#   ✅ P-M-134 — Intersection found
#      Bounds: (-5232016.067283858, -3343864.9538337365, -5204186.194585539, -3312159.8598184385)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ PN-T-68 — Intersection found
#      Bounds: (-4953717.340300674, -557596.2597104559, -4898057.594904037, -501453.5101383216)
#      Priority level(s): High
#      Overlap: 0.29%
#   ✅ P-M-1664 — Intersection found
#      Bounds: (-5649464.157758634, -4028802.026134409, -5621634.285060315, -3995282.329624239)
#      Priority level(s): High, Very High
#      Overlap: 100.00%
#   ✅ PN-T-48 — Intersection found
#      Bounds: (-5065082.273453441, -501495.86395164643, -5042180.412858545, -445682.02009652485)
#      Priority level(s): High, Very High
#      Overlap: 43.20%
#   ✅ PN-T-48A — Intersection found
#      Bounds: (-5065036.831093947, -501453.5101383216, -5009377.085697311, -445640.10965602624)
#      Priority level(s): High, Very High
#      Overlap: 26.98%
#   ✅ P-M-1666 — Intersection found
#      Bounds: (-5621634.285060315, -4028802.026134409, -5593804.412361997, -3995282.329624239)
#      Priority level(s): High, Very High
#      Overlap: 100.00%
#   ✅ P-M-1733 — Intersection found
#      Bounds: (-5649464.157758634, -4062420.520415545, -5621634.285060315, -4028802.026134409)
#      Priority level(s): High, Very High
#      Overlap: 100.00%
#   ✅ P-M-1735 — Intersection found
#      Bounds: (-5621634.285060315, -4062420.520415545, -5593804.412361997, -4028802.026134409)
#      Priority level(s): High, Very High
#      Overlap: 100.00%
#   ✅ P-M-1791 — Intersection found
#      Bounds: (-5649464.157758634, -4096139.0404472337, -5621634.285060315, -4062420.520415545)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-190 — Intersection found
#      Bounds: (-5287675.812680495, -3375646.034919311, -5259845.939982176, -3343864.9538337365)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ P-M-192 — Intersection found
#      Bounds: (-5259845.939982176, -3375646.034919311, -5232016.067283858, -3343864.9538337365)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ P-M-194 — Intersection found
#      Bounds: (-5232016.067283858, -3375646.034919311, -5204186.194585539, -3343864.9538337365)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ P-M-22 — Intersection found
#      Bounds: (-5259845.939982176, -3280529.7896193247, -5232016.067283858, -3248973.789650975)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ P-M-24 — Intersection found
#      Bounds: (-5232016.067283858, -3280529.7896193247, -5204186.194585539, -3248973.789650975)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ P-M-76 — Intersection found
#      Bounds: (-5259845.939982176, -3312159.8598184385, -5232016.067283858, -3280529.7896193247)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ P-M-78 — Intersection found
#      Bounds: (-5232016.067283858, -3312159.8598184385, -5204186.194585539, -3280529.7896193247)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ PN-T-47 — Intersection found
#      Bounds: (-5120696.576490585, -501453.5101383216, -5065036.831093947, -445640.10965602624)
#      Priority level(s): High, Very High
#      Overlap: 11.69%
#   ❌ PAMA-M-192 — No intersection
#      Bounds: (-5092912.246382316, 83454.16515842607, -5065082.15303228, 111287.52256411007)
#      Min. distance to priority area: 5319.97 meters
#   ✅ POT-T-742 — Intersection found
#      Bounds: (-4174480.904747759, -613243.4340891504, -4167523.436573179, -608540.0613252178)
#      Priority level(s): Extremely High
#      Overlap: 15.99%
#   ❌ REC-T-120 — No intersection
#      Bounds: (-4246124.286244747, -1374173.3093312215, -4237098.118318975, -1369427.301606193)
#      Min. distance to priority area: 22801.48 meters
#   ❌ REC-T-119 — No intersection
#      Bounds: (-4251052.536625858, -1374223.609814544, -4246414.177150238, -1369427.301606193)
#      Min. distance to priority area: 31683.85 meters
#   ❌ POT-T-793 — No intersection
#      Bounds: (-4146651.0320494403, -617859.5916672364, -4139693.563874861, -613199.6633499706)
#      Min. distance to priority area: 12977.71 meters
#   ❌ REC-T-45 — No intersection
#      Bounds: (-4271885.459191873, -1340966.8396748896, -4264927.991017294, -1336226.0012057717)
#      Min. distance to priority area: 4909.68 meters
#   ❌ REC-T-56 — No intersection
#      Bounds: (-4264927.991017294, -1345708.4084091089, -4257970.522842714, -1340966.8396748896)
#      Min. distance to priority area: 8923.72 meters
#   ❌ REC-T-76 — No intersection
#      Bounds: (-4264967.571285634, -1355243.869598878, -4258010.041261945, -1350500.7927573647)
#      Min. distance to priority area: 9740.43 meters
#   ✅ REC-T-82 — Intersection found
#      Bounds: (-4285800.395541033, -1359937.5234664993, -4278842.927366453, -1355193.747562799)
#      Priority level(s): High
#      Overlap: 40.11%
#   ✅ AM-T-85 — Intersection found
#      Bounds: (-6512190.211406504, -334111.1714019596, -6456530.466009867, -287672.8359997089)
#      Priority level(s): Extremely High, Very High
#      Overlap: 38.83%
#   ❌ REC-T-85 — No intersection
#      Bounds: (-4264927.991017294, -1359937.5234664993, -4257970.522842714, -1355193.747562799)
#      Min. distance to priority area: 12406.33 meters
#   ❌ REC-T-86 — No intersection
#      Bounds: (-4257970.522842714, -1359937.5234664993, -4251013.054668135, -1355193.747562799)
#      Min. distance to priority area: 18104.96 meters
#   ❌ C-M-661 — No intersection
#      Bounds: (-4452779.631730943, -2753408.10936498, -4424949.759032625, -2722973.976836009)
#      Min. distance to priority area: 30735.34 meters
#   ❌ ALTO_CF_CE — No intersection
#      Bounds: (-4619179.078906309, -2819871.528774223, -4528152.203622218, -2735964.6991360276)
#      Min. distance to priority area: 11222.30 meters
#   ❌ REC-T-142 — No intersection
#      Bounds: (-4264967.606525255, -1384014.6922132724, -4258010.072750779, -1378970.3864418957)
#      Min. distance to priority area: 26750.81 meters
#   ✅ S-M-1356 — Intersection found
#      Bounds: (-5120696.576490585, -3092272.122885536, -5092866.703792266, -3061141.038886033)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ❌ REC-T-129 — No intersection
#      Bounds: (-4264967.602623084, -1378970.3956930893, -4258010.066535522, -1374223.5879431681)
#      Min. distance to priority area: 23392.01 meters
#   ✅ PAMA-M-337 — Intersection found
#      Bounds: (-4981591.8747536335, 27791.700160368007, -4953761.779741475, 55622.40965547703)
#      Priority level(s): Extremely High
#      Overlap: 1.78%
#   ❌ SEAL-T-132 — No intersection
#      Bounds: (-3993586.732208689, -1085935.5613933296, -3986629.2640341097, -1081230.1509776185)
#      Min. distance to priority area: 2863.48 meters
#   ❌ FZA-M-57 — No intersection
#      Bounds: (-5621684.013589497, 585212.5136021555, -5593853.919319305, 613165.5382294282)
#      Min. distance to priority area: 17884.19 meters
#   ❌ FZA-M-88 — No intersection
#      Bounds: (-5593853.919319305, 557270.7340363346, -5566023.825219433, 585212.5533956072)
#      Min. distance to priority area: 20086.96 meters
#   ✅ S-M-1482 — Intersection found
#      Bounds: (-5120696.576490585, -3123471.749104577, -5092866.703792266, -3092272.122885536)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ FZA-M-539 — Intersection found
#      Bounds: (-5426873.343747831, 375885.0010755683, -5412958.297591455, 389825.1293694136)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ❌ ES-T-226 — No intersection
#      Bounds: (-4424369.9700180795, -2071716.026810968, -4417992.290858044, -2066831.4600854982)
#      Min. distance to priority area: 4143.81 meters
#   ❌ C-M-757 — No intersection
#      Bounds: (-4480609.504429261, -2814454.7323097703, -4452779.631730943, -2783901.423375836)
#      Min. distance to priority area: 35833.96 meters
#   ❌ ES-T-305 — No intersection
#      Bounds: (-4431907.227207203, -2101048.1985014575, -4427268.915090814, -2096156.5384662861)
#      Min. distance to priority area: 4680.40 meters
#   ✅ S-M-1378 — Intersection found
#      Bounds: (-4814567.976809082, -3123471.749104577, -4758908.231412445, -3063408.716429815)
#      Priority level(s): High
#      Overlap: 21.38%
#   ❌ ES-T-380 — No intersection
#      Bounds: (-4452779.631730943, -2135323.408540677, -4444082.796512718, -2130423.3287959015)
#      Min. distance to priority area: 11752.26 meters
#   ✅ ES-T-409 — Intersection found
#      Bounds: (-4435428.422461307, -2150087.7298945887, -4431907.227207203, -2145127.2179014175)
#      Priority level(s): Extremely High
#      Overlap: 80.80%
#   ✅ ES-T-429 — Intersection found
#      Bounds: (-4438864.695381784, -2159842.1046241894, -4431659.770560613, -2154379.535969245)
#      Priority level(s): Extremely High
#      Overlap: 76.31%
#   ❌ REC-T-103 — No intersection
#      Bounds: (-4285800.395541033, -1374223.5686910357, -4278842.927366453, -1364682.0405658449)
#      Min. distance to priority area: 5598.45 meters
#   ✅ TUC-T-140 — Intersection found
#      Bounds: (-4299755.118539737, -1274709.7016502356, -4285800.395541033, -1260469.6774541626)
#      Priority level(s): Extremely High
#      Overlap: 1.08%
#   ❌ SEAL-T-151 — No intersection
#      Bounds: (-4033882.0687197996, -1095396.2496978005, -4022903.1992905918, -1090641.5572689108)
#      Min. distance to priority area: 21408.00 meters
#   ❌ SEAL-T-167 — No intersection
#      Bounds: (-4014459.1367324283, -1100055.3159416579, -4007501.6685578483, -1095396.2580655806)
#      Min. distance to priority area: 5318.16 meters
#   ❌ SEAL-T-102 — No intersection
#      Bounds: (-4000544.200383269, -1070693.0223277267, -3993586.732208689, -1067117.406162763)
#      Min. distance to priority area: 19618.68 meters
#   ❌ SEAL-T-110 — No intersection
#      Bounds: (-4007501.6685578483, -1076573.286737391, -4000544.200383269, -1071821.0759934357)
#      Min. distance to priority area: 19132.51 meters
#   ✅ TUC-T-177 — Intersection found
#      Bounds: (-4299715.331890192, -1359937.5234664993, -4285800.395541033, -1345758.3938906628)
#      Priority level(s): High
#      Overlap: 26.86%
#   ❌ SEAL-T-120 — No intersection
#      Bounds: (-3993586.732208689, -1081230.1509776185, -3986629.2640341097, -1076525.3233882855)
#      Min. distance to priority area: 8378.07 meters
#   ❌ SEAL-T-141 — No intersection
#      Bounds: (-4021416.6049070074, -1090641.5572689108, -4014459.1367324283, -1085935.5613933296)
#      Min. distance to priority area: 17854.11 meters
#   ❌ C-M-659 — No intersection
#      Bounds: (-4480609.504429261, -2753408.10936498, -4452779.631730943, -2692598.2193217897)
#      Min. distance to priority area: 55270.96 meters
#   ❌ ES-T-398 — No intersection
#      Bounds: (-4452779.631730943, -2145127.2179014175, -4445822.163556363, -2140224.7038436625)
#      Min. distance to priority area: 11287.26 meters
#   ❌ ES-T-389 — No intersection
#      Bounds: (-4452779.631730943, -2140224.7038436625, -4444125.304185342, -2135323.408540677)
#      Min. distance to priority area: 10630.68 meters
#   ❌ C-M-713 — No intersection
#      Bounds: (-4480609.504429261, -2783901.423375836, -4452779.631730943, -2753408.10936498)
#      Min. distance to priority area: 66387.27 meters
#   ❌ REC-T-67 — No intersection
#      Bounds: (-4257970.522842714, -1350450.7101266168, -4251013.054668135, -1345708.4084091089)
#      Min. distance to priority area: 15863.03 meters
#   ❌ REC-T-58 — No intersection
#      Bounds: (-4251013.054668135, -1345758.4662610434, -4244055.5864935545, -1340966.8396786787)
#      Min. distance to priority area: 21084.58 meters
#   ❌ SEAL-M-505 — No intersection
#      Bounds: (-3979671.7958595306, -1288857.1804959085, -3951841.9231612114, -1260469.6774541626)
#      Min. distance to priority area: 63727.15 meters
#   ❌ SEAL-M-575 — No intersection
#      Bounds: (-4007501.6685578483, -1317269.89523635, -3979671.7958595306, -1288857.1804959085)
#      Min. distance to priority area: 83061.84 meters
#   ❌ SEAL-M-637 — No intersection
#      Bounds: (-4035331.5412561675, -1345708.4084091089, -4007501.6685578483, -1317269.89523635)
#      Min. distance to priority area: 79478.91 meters
#   ❌ PAR-T-218 — No intersection
#      Bounds: (-5822586.120065053, -2571719.550218981, -5788668.1599749, -2511581.185314419)
#      Min. distance to priority area: 26568.89 meters
#   ❌ PAR-T-198 — No intersection
#      Bounds: (-5788668.1599749, -2511581.4740143144, -5733007.9149389295, -2476598.783720114)
#      Min. distance to priority area: 25998.46 meters
#   ❌ LIBRA — No intersection
#      Bounds: (-4694551.650797584, -2849857.8608762845, -4667011.672606544, -2816047.709570424)
#      Min. distance to priority area: 18675.17 meters
#   ❌ REC-T-183 — No intersection
#      Bounds: (-4258010.097839587, -1397965.1427522346, -4255361.472277247, -1393215.3154346275)
#      Min. distance to priority area: 24635.44 meters
#   ✅ POT-T-525 — Intersection found
#      Bounds: (-4104943.6903354316, -589904.8659913753, -4097948.7548273834, -582335.7609054678)
#      Priority level(s): High, Extremely High
#      Overlap: 100.32%
#   ❌ POT-T-654 — No intersection
#      Bounds: (-4146651.0320494403, -604798.0843189409, -4139693.563874861, -599221.8261269907)
#      Min. distance to priority area: 12706.12 meters
#   ✅ POT-T-436 — Intersection found
#      Bounds: (-4111863.691176542, -579759.3914023703, -4104906.223001963, -575931.7726758609)
#      Priority level(s): Extremely High
#      Overlap: 91.95%
#   ✅ POT-T-696 — Intersection found
#      Bounds: (-4174518.998397444, -608540.061328945, -4167523.436573179, -603880.7830908563)
#      Priority level(s): Extremely High
#      Overlap: 58.39%
#   ✅ POT-T-435 — Intersection found
#      Bounds: (-4118858.7481725942, -582379.2939118565, -4111863.691176542, -575931.7726758609)
#      Priority level(s): Extremely High
#      Overlap: 0.07%
#   ❌ POT-T-609 — No intersection
#      Bounds: (-4146651.0320494403, -599221.8261269907, -4139693.563874861, -594563.187929497)
#      Min. distance to priority area: 10594.91 meters
#   ❌ POT-T-281 — No intersection
#      Bounds: (-4117409.2487413157, -557305.2572745768, -4111901.203107026, -552649.3752593638)
#      Min. distance to priority area: 3889.29 meters
#   ❌ POT-T-391 — No intersection
#      Bounds: (-4137412.1570015955, -575931.7726758609, -4129874.830263114, -570153.8866213394)
#      Min. distance to priority area: 2791.57 meters
#   ❌ S-M-536 — No intersection
#      Bounds: (-4571926.274220618, -2875744.624352243, -4536269.249825899, -2845068.856710045)
#      Min. distance to priority area: 18899.22 meters
#   ✅ PAR-T-196 — Intersection found
#      Bounds: (-5899933.012043499, -2511525.2348457123, -5844273.266646863, -2451599.087377855)
#      Priority level(s): Extremely High
#      Overlap: 33.11%
#   ✅ POT-T-650 — Intersection found
#      Bounds: (-4174480.904747759, -603880.7830908563, -4167523.436573179, -599221.8261269907)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ❌ POT-T-566 — No intersection
#      Bounds: (-4132773.8139890702, -594563.187929497, -4125816.2818668643, -589904.8659913753)
#      Min. distance to priority area: 4765.63 meters
#   ❌ REC-T-68 — No intersection
#      Bounds: (-4251052.505938391, -1350500.8093426274, -4244094.969969696, -1345758.4572639703)
#      Min. distance to priority area: 22781.05 meters
#   ❌ POT-T-564 — No intersection
#      Bounds: (-4146651.0320494403, -594606.8140195201, -4139693.563874861, -589904.8659913753)
#      Min. distance to priority area: 6573.51 meters
#   ✅ PAR-T-215 — Intersection found
#      Bounds: (-6011252.502836772, -2571663.0471736453, -5955592.757440136, -2511525.2348457123)
#      Priority level(s): Extremely High
#      Overlap: 0.85%
#   ❌ POT-T-521 — No intersection
#      Bounds: (-4132736.095700281, -589904.8659913753, -4126358.416540246, -585246.8578064678)
#      Min. distance to priority area: 186.31 meters
#   ❌ POT-T-519 — No intersection
#      Bounds: (-4146688.8692346364, -589904.8659913753, -4139693.563874861, -585246.8578064678)
#      Min. distance to priority area: 3143.17 meters
#   ✅ POT-T-432 — Intersection found
#      Bounds: (-4140311.1301102433, -580589.1608694581, -4132736.095700281, -575931.7726758609)
#      Priority level(s): High
#      Overlap: 28.30%
#   ❌ POT-T-434 — No intersection
#      Bounds: (-4125778.627525702, -580589.1608694581, -4118821.159351122, -575931.7726758609)
#      Min. distance to priority area: 4813.49 meters
#   ✅ POT-T-477 — Intersection found
#      Bounds: (-4132736.095700281, -585290.4106278933, -4125778.627525702, -580589.1608694581)
#      Priority level(s): High
#      Overlap: 20.46%
#   ❌ POT-T-225 — No intersection
#      Bounds: (-4153608.5002240203, -543338.4899307952, -4146651.0320494403, -538683.4816205008)
#      Min. distance to priority area: 114.92 meters
#   ❌ TUC-T-172 — No intersection
#      Bounds: (-4313630.268239351, -1345708.4084091089, -4299755.189573929, -1331485.8902476795)
#      Min. distance to priority area: 7788.03 meters
#   ✅ POT-T-211 — Intersection found
#      Bounds: (-4153608.5002240203, -538683.4816205008, -4147520.715571263, -534028.7595495306)
#      Priority level(s): Extremely High
#      Overlap: 62.01%
#   ✅ POT-T-223 — Intersection found
#      Bounds: (-4167523.436573179, -543338.4899307952, -4160565.9683986, -538683.4816205008)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ✅ POT-T-224 — Intersection found
#      Bounds: (-4160565.9683986, -543338.4899307952, -4153608.5002240203, -538683.4816205008)
#      Priority level(s): Extremely High
#      Overlap: 53.33%
#   ✅ POT-T-257 — Intersection found
#      Bounds: (-4146651.0320494403, -552649.3752593638, -4139693.563874861, -547993.7869777231)
#      Priority level(s): High
#      Overlap: 26.96%
#   ✅ POT-T-276 — Intersection found
#      Bounds: (-4153608.5002240203, -557305.2572745768, -4146651.0320494403, -552649.3752593638)
#      Priority level(s): High
#      Overlap: 6.67%
#   ✅ POT-T-298 — Intersection found
#      Bounds: (-4153608.5002240203, -561961.4355230022, -4146651.0320494403, -557305.2572745768)
#      Priority level(s): High
#      Overlap: 15.12%
#   ✅ P-M-1599 — Intersection found
#      Bounds: (-5454655.048870405, -3995282.329624239, -5426825.176172087, -3961860.2174457465)
#      Priority level(s): High
#      Overlap: 100.00%
#   ❌ REC-T-155 — No intersection
#      Bounds: (-4265257.512219195, -1388466.2513025638, -4258010.082507688, -1383717.9382928978)
#      Min. distance to priority area: 30988.39 meters
#   ❌ S-M-518 — No intersection
#      Bounds: (-4798043.989894455, -2875806.850858839, -4786785.544266479, -2849538.5470476705)
#      Min. distance to priority area: 56951.13 meters
#   ✅ P-M-1522 — Intersection found
#      Bounds: (-5426825.176172087, -3961860.2174457465, -5398995.303473768, -3928534.4904265907)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1595 — Intersection found
#      Bounds: (-5510314.794267042, -3995282.329624239, -5482484.921568723, -3961860.2174457465)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1597 — Intersection found
#      Bounds: (-5482484.921568723, -3995282.329624239, -5454655.048870405, -3961860.2174457465)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1674 — Intersection found
#      Bounds: (-5510314.794267042, -4028802.026134409, -5482484.921568723, -3995282.329624239)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1676 — Intersection found
#      Bounds: (-5482484.921568723, -4028802.026134409, -5454655.048870405, -3995282.329624239)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1678 — Intersection found
#      Bounds: (-5454655.048870405, -4028802.026134409, -5426825.176172087, -3995282.329624239)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1743 — Intersection found
#      Bounds: (-5510314.794267042, -4062420.520415545, -5482484.921568723, -4028802.026134409)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1793 — Intersection found
#      Bounds: (-5621634.285060315, -4096139.0404472337, -5593804.412361997, -4062420.520415545)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1795 — Intersection found
#      Bounds: (-5593804.412361997, -4096139.0404472337, -5565974.539663678, -4062420.520415545)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1799 — Intersection found
#      Bounds: (-5538144.666965361, -4096139.0404472337, -5510314.794267042, -4062420.520415545)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1838 — Intersection found
#      Bounds: (-5621634.285060315, -4129958.8290286926, -5593804.412361997, -4096139.0404472337)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ P-M-1840 — Intersection found
#      Bounds: (-5593804.412361997, -4129958.8290286926, -5565974.539663678, -4096139.0404472337)
#      Priority level(s): High
#      Overlap: 100.00%
#   ❌ SEAL-M-351 — No intersection
#      Bounds: (-4007538.79477873, -1232106.8018967598, -3979671.7958595306, -1203767.9720651004)
#      Min. distance to priority area: 3889.50 meters
#   ❌ ES-T-399 — No intersection
#      Bounds: (-4445822.163556363, -2145127.2179014175, -4442096.034928071, -2140224.7038436625)
#      Min. distance to priority area: 7636.47 meters
#   ❌ BAR-M-300 — No intersection
#      Bounds: (-4703290.917728175, -194879.46549952342, -4675460.810421235, -167038.143018107)
#      Min. distance to priority area: 81203.65 meters
#   ❌ BAR-M-298 — No intersection
#      Bounds: (-4731121.019038489, -194879.4598216194, -4703290.912511209, -167038.13812522366)
#      Min. distance to priority area: 94472.95 meters
#   ❌ ES-T-407 — No intersection
#      Bounds: (-4452779.631730943, -2150030.953914176, -4445822.163556363, -2145127.2179014175)
#      Min. distance to priority area: 10206.77 meters
#   ❌ BAR-M-175 — No intersection
#      Bounds: (-4814611.304554059, -111364.51173653346, -4786781.202910934, -83531.14608265272)
#      Min. distance to priority area: 30126.53 meters
#   ❌ BM-BAR-3 — No intersection
#      Bounds: (-4835483.877568519, -111364.50842233763, -4814611.303506977, -102086.50932257787)
#      Min. distance to priority area: 14861.24 meters
#   ❌ BM-BAR-1 — No intersection
#      Bounds: (-4765908.642683298, -204160.68840077505, -4731121.018108192, -176318.1906448068)
#      Min. distance to priority area: 88620.54 meters
#   ✅ BLC_UIRAPR — Intersection found
#      Bounds: (-4898637.3839185815, -2916742.9818927837, -4866169.199103884, -2850815.8425824335)
#      Priority level(s): Extremely High
#      Overlap: 1.14%
#   ❌ REC-T-110 — No intersection
#      Bounds: (-4237098.118318975, -1369427.301606193, -4230140.650144396, -1364978.5975572553)
#      Min. distance to priority area: 19734.77 meters
#   ❌ TUC-T-147 — No intersection
#      Bounds: (-4313670.194766678, -1288906.6736656479, -4299755.118539737, -1274709.6671874318)
#      Min. distance to priority area: 2279.23 meters
#   ❌ POT-T-610 — No intersection
#      Bounds: (-4139693.563874861, -599221.8261269907, -4131286.6231639143, -594563.187929497)
#      Min. distance to priority area: 9359.96 meters
#   ❌ REC-T-180 — No intersection
#      Bounds: (-4278842.927366453, -1399152.6869077287, -4274204.615250063, -1393164.8620242823)
#      Min. distance to priority area: 21538.98 meters
#   ❌ ES-T-408 — No intersection
#      Bounds: (-4445822.163556363, -2150030.953914176, -4440936.459644399, -2145127.2179014175)
#      Min. distance to priority area: 5327.34 meters
#   ✅ SF-T-132 — Intersection found
#      Bounds: (-5120744.948080235, -2154991.2680637008, -5065084.602574884, -2096211.2814123363)
#      Priority level(s): High
#      Overlap: 83.34%
#   ✅ AM-T-62 — Intersection found
#      Bounds: (-6456530.466009867, -278387.0759542351, -6400870.72061323, -222684.20850554405)
#      Priority level(s): Extremely High, High, Very High
#      Overlap: 31.88%
#   ✅ N_DE_BRAVA — Intersection found
#      Bounds: (-4473405.899274883, -2551966.9326344295, -4445575.745970241, -2541940.7230862463)
#      Priority level(s): Extremely High
#      Overlap: 0.10%
#   ❌ TUC-T-139 — No intersection
#      Bounds: (-4313670.177260698, -1274709.6844453535, -4299755.101290882, -1260518.908047918)
#      Min. distance to priority area: 1397.28 meters
#   ❌ REC-T-59 — No intersection
#      Bounds: (-4244094.969969696, -1345758.4752440278, -4237137.433995692, -1341016.8561790416)
#      Min. distance to priority area: 16835.17 meters
#   ❌ BAR-M-388 — No intersection
#      Bounds: (-4675460.824892568, -236648.57108451796, -4661545.770221366, -222724.49496522642)
#      Min. distance to priority area: 37220.96 meters
#   ❌ BAR-M-387 — No intersection
#      Bounds: (-4689375.876077623, -236648.56765087947, -4675460.8215983575, -222724.49172488877)
#      Min. distance to priority area: 44385.43 meters
#   ✅ SF-T-114 — Intersection found
#      Bounds: (-5009424.129729497, -1979160.6803782173, -4953763.796536794, -1920878.6253251575)
#      Priority level(s): Very High, High
#      Overlap: 59.82%
#   ✅ SF-T-104 — Intersection found
#      Bounds: (-5009424.003201805, -1920878.7451822478, -4953763.67542877, -1862751.9874852656)
#      Priority level(s): Very High
#      Overlap: 35.60%
#   ❌ S-M-623 — No intersection
#      Bounds: (-4925936.325997749, -2906544.9780712733, -4907092.9482909, -2885405.4383203196)
#      Min. distance to priority area: 7119.67 meters
#   ✅ PAU_BRASIL — Intersection found
#      Bounds: (-4727889.519134115, -2999080.943470641, -4682376.081492069, -2947565.8445166694)
#      Priority level(s): High
#      Overlap: 92.02%
#   ❌ FZA-M-90 — No intersection
#      Bounds: (-5566023.844382404, 557270.75294213, -5538193.749422789, 585212.5731703218)
#      Min. distance to priority area: 33956.77 meters
#   ❌ FZA-M-254 — No intersection
#      Bounds: (-5552108.752022752, 487461.73795484036, -5538193.705832503, 501418.6233968246)
#      Min. distance to priority area: 693.79 meters
#   ✅ POT-T-741 — Intersection found
#      Bounds: (-4182018.161936883, -613199.6633499706, -4174480.904747759, -608540.061328945)
#      Priority level(s): Extremely High
#      Overlap: 96.40%
#   ✅ ARAM — Intersection found
#      Bounds: (-5023002.127539192, -2993921.2629419346, -4932844.935776935, -2906482.870376794)
#      Priority level(s): Very High, Extremely High
#      Overlap: 12.36%
#   ❌ FZA-M-127 — No intersection
#      Bounds: (-5566023.825219433, 529339.6171355057, -5538193.731281296, 557270.7717703563)
#      Min. distance to priority area: 15055.50 meters
#   ✅ ES-T-516 — Intersection found
#      Bounds: (-4438907.294688571, -2199193.441667149, -4431949.753068831, -2194277.2503506145)
#      Priority level(s): Extremely High
#      Overlap: 98.54%
#   ✅ ES-M-671 — Intersection found
#      Bounds: (-4313672.095098877, -2362152.6067609396, -4285841.897884474, -2332416.484391234)
#      Priority level(s): Very High
#      Overlap: 2.13%
#   ✅ ES-M-743 — Intersection found
#      Bounds: (-4313672.164350099, -2391937.863635013, -4285841.965697313, -2362152.5419177026)
#      Priority level(s): Very High
#      Overlap: 0.33%
#   ✅ FZA-M-125 — Intersection found
#      Bounds: (-5593853.90007772, 529339.5991793923, -5566023.807002877, 557270.75294213)
#      Priority level(s): Extremely High
#      Overlap: 0.64%
#   ❌ ES-M-669 — No intersection
#      Bounds: (-4341502.223704097, -2362152.5419177026, -4313672.026867277, -2332416.4200053774)
#      Min. distance to priority area: 24815.39 meters
#   ✅ ES-M-596 — Intersection found
#      Bounds: (-4313672.026867277, -2332416.5483837575, -4285841.831077406, -2302728.898812899)
#      Priority level(s): Very High
#      Overlap: 3.98%
#   ✅ FZA-M-86 — Intersection found
#      Bounds: (-5621683.993313642, 557270.7150533317, -5593853.90007772, 585212.5335394259)
#      Priority level(s): Extremely High
#      Overlap: 0.50%
#   ❌ FZA-M-59 — No intersection
#      Bounds: (-5593853.93951305, 585212.5335394259, -5566023.844382404, 613165.5590367349)
#      Min. distance to priority area: 37402.48 meters
#   ✅ SO_TRTG_VD — Intersection found
#      Bounds: (-4546415.55758049, -2641154.163393698, -4529311.781651318, -2626350.8827114445)
#      Priority level(s): Extremely High
#      Overlap: 32.41%
#   ✅ POT-T-192 — Intersection found
#      Bounds: (-4195353.309271498, -534028.7595495306, -4190753.1931410558, -529374.3212213356)
#      Priority level(s): Extremely High
#      Overlap: 14.73%
#   ✅ POT-M-952 — Intersection found
#      Bounds: (-3951841.9231612114, -529374.3212213356, -3924012.0504628937, -501453.5101383216)
#      Priority level(s): Extremely High
#      Overlap: 25.75%
#   ✅ ES-T-504 — Intersection found
#      Bounds: (-4452779.631730943, -2194220.095879528, -4445822.163556363, -2189305.217648381)
#      Priority level(s): Extremely High
#      Overlap: 37.62%
#   ✅ ES-T-514 — Intersection found
#      Bounds: (-4452779.631730943, -2199136.228272881, -4445822.163556363, -2194220.095879528)
#      Priority level(s): Extremely High
#      Overlap: 99.50%
#   ✅ ES-T-525 — Intersection found
#      Bounds: (-4452779.631730943, -2204053.6180698806, -4445822.163556363, -2199136.228272881)
#      Priority level(s): Extremely High
#      Overlap: 98.63%
#   ✅ POT-T-194 — Intersection found
#      Bounds: (-4181476.4881542902, -534028.7595495306, -4174480.904747759, -525926.6892070641)
#      Priority level(s): Extremely High
#      Overlap: 77.57%
#   ✅ POT-T-195 — Intersection found
#      Bounds: (-4174480.904747759, -534028.7595495306, -4168972.909109547, -525926.6903532601)
#      Priority level(s): Extremely High
#      Overlap: 35.21%
#   ✅ REC-T-24 — Intersection found
#      Bounds: (-4216264.831973787, -1334498.3700586983, -4209268.245620657, -1322007.8399911385)
#      Priority level(s): High
#      Overlap: 27.85%
#   ❌ REC-T-165 — No intersection
#      Bounds: (-4285550.309040078, -1402715.6979630194, -4278842.927366453, -1388712.6317273472)
#      Min. distance to priority area: 17266.21 meters
#   ✅ POT-T-834 — Intersection found
#      Bounds: (-4188434.0635900423, -622519.8487800073, -4181438.372922338, -617859.5916635087)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ❌ BM-S-24 — No intersection
#      Bounds: (-4731125.621157092, -2952772.3764292924, -4689380.255123399, -2896292.4291919926)
#      Min. distance to priority area: 2823.93 meters
#   ✅ ES-T-373 — Intersection found
#      Bounds: (-4437747.557370942, -2131092.387831586, -4430210.223432684, -2124968.7445748625)
#      Priority level(s): Extremely High
#      Overlap: 26.76%
#   ❌ REC-T-109 — No intersection
#      Bounds: (-4244055.5864935545, -1369427.301606193, -4237098.118318975, -1364682.0405658449)
#      Min. distance to priority area: 25269.26 meters
#   ✅ POT-T-196 — Intersection found
#      Bounds: (-4167523.436573179, -534028.7595495306, -4160565.9683986, -529374.3212213356)
#      Priority level(s): Extremely High
#      Overlap: 58.32%
#   ✅ POT-T-197 — Intersection found
#      Bounds: (-4160565.9683986, -534028.7595495306, -4153608.5002240203, -529374.3212213356)
#      Priority level(s): Extremely High
#      Overlap: 26.82%
#   ✅ ES-T-487 — Intersection found
#      Bounds: (-4431907.227207203, -2184755.7455419446, -4424949.759032625, -2179479.210721923)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ❌ POT-T-204 — No intersection
#      Bounds: (-4202310.777446077, -538683.4816205008, -4195353.309271498, -534028.7595495306)
#      Min. distance to priority area: 3346.03 meters
#   ✅ POT-T-207 — Intersection found
#      Bounds: (-4181438.372922338, -538683.4816205008, -4174480.904747759, -534028.7595495306)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ✅ POT-T-208 — Intersection found
#      Bounds: (-4174480.904747759, -538683.4816205008, -4167523.436573179, -534028.7595495306)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ✅ POT-T-209 — Intersection found
#      Bounds: (-4167523.436573179, -538683.4816205008, -4160565.9683986, -534028.7595495306)
#      Priority level(s): Extremely High
#      Overlap: 100.00%
#   ✅ POT-T-210 — Intersection found
#      Bounds: (-4160565.9683986, -538683.4816205008, -4153608.5002240203, -534028.7595495306)
#      Priority level(s): Extremely High
#      Overlap: 37.55%
#   ❌ SEAL-M-428 — No intersection
#      Bounds: (-4007538.826442502, -1260469.6774541626, -3979671.7958595306, -1232106.8018967598)
#      Min. distance to priority area: 32228.33 meters
#   ✅ SOL-T-192 — Intersection found
#      Bounds: (-7378974.788156209, -565744.8002007339, -7347376.286863333, -557346.3262133203)
#      Priority level(s): Very High, High
#      Overlap: 68.69%
#   ❌ TITA — No intersection
#      Bounds: (-4576854.480844275, -2863914.3184337076, -4558301.232378737, -2827840.879944236)
#      Min. distance to priority area: 24250.64 meters
#   ✅ S-M-647 — Intersection found
#      Bounds: (-4615700.344819019, -2906482.870376794, -4564099.122524217, -2875744.624352243)
#      Priority level(s): High
#      Overlap: 43.59%
#   ✅ PAR-T-86 — Intersection found
#      Bounds: (-5844273.266646863, -2154935.915085894, -5788613.521250226, -2096156.5384662861)
#      Priority level(s): Very High
#      Overlap: 43.03%
#   ✅ PAR-T-99 — Intersection found
#      Bounds: (-6011252.502836772, -2213892.1828597235, -5955592.757440136, -2154935.915085894)
#      Priority level(s): High
#      Overlap: 17.53%
#   ❌ REC-T-108 — No intersection
#      Bounds: (-4251052.530443007, -1369427.301606193, -4247244.426073567, -1366461.4261280717)
#      Min. distance to priority area: 30297.20 meters
#   ❌ SEAL-T-166 — No intersection
#      Bounds: (-4019134.541050097, -1102457.3051531347, -4013589.453210606, -1095348.1412394529)
#      Min. distance to priority area: 11390.55 meters
#   ❌ SEAL-T-187 — No intersection
#      Bounds: (-4035331.5412561675, -1109471.4480959692, -4028374.0730815874, -1104763.0840138483)
#      Min. distance to priority area: 15474.56 meters
#   ✅ PN-T-149 — Intersection found
#      Bounds: (-5004158.984566376, -837335.7520792983, -4956036.496358864, -781182.2141882492)
#      Priority level(s): High, Extremely High
#      Overlap: 8.75%
#   ❌ SEAL-T-252 — No intersection
#      Bounds: (-4035331.5412561675, -1137734.296840986, -4028374.0730815874, -1133022.3011684045)
#      Min. distance to priority area: 2018.66 meters
#   ✅ SEAL-T-253 — Intersection found
#      Bounds: (-4028374.0730815874, -1137734.296840986, -4021416.6049070074, -1133022.3011684045)
#      Priority level(s): Extremely High
#      Overlap: 0.13%
#   ❌ POT-T-568 — No intersection
#      Bounds: (-4118858.753178097, -594606.8293953134, -4111863.691176542, -589904.8659913753)
#      Min. distance to priority area: 2757.82 meters
#   ❌ POT-T-327 — No intersection
#      Bounds: (-4111863.691176542, -566617.9125050706, -4104906.223001963, -561961.4355230022)
#      Min. distance to priority area: 3231.15 meters
#   ❌ POT-T-520 — No intersection
#      Bounds: (-4139693.563874861, -589948.4554779181, -4132736.095700281, -585246.8578064678)
#      Min. distance to priority area: 0.00 meters
#   ❌ POT-T-304 — No intersection
#      Bounds: (-4111863.691176542, -562004.7956750272, -4104906.223001963, -557305.2572745768)
#      Min. distance to priority area: 3360.44 meters
#   ✅ POT-T-524 — Intersection found
#      Bounds: (-4111863.691176542, -589948.4691262101, -4104906.223001963, -585246.8578064678)
#      Priority level(s): Extremely High
#      Overlap: 62.87%
#   ✅ POT-T-437 — Intersection found
#      Bounds: (-4104943.6878583836, -582335.7609054678, -4097948.7548273834, -575931.7726758609)
#      Priority level(s): Extremely High
#      Overlap: 98.78%
#   ✅ POT-T-605 — Intersection found
#      Bounds: (-4174480.904747759, -599221.8261269907, -4167523.436573179, -594563.187929497)
#      Priority level(s): Extremely High
#      Overlap: 87.00%
#   ❌ POT-T-608 — No intersection
#      Bounds: (-4153608.5002240203, -599221.8261269907, -4146651.0320494403, -594563.187929497)
#      Min. distance to priority area: 4490.27 meters
#   ✅ POT-T-697 — Intersection found
#      Bounds: (-4167523.436573179, -608540.061328945, -4160565.9683986, -603880.7830908563)
#      Priority level(s): Extremely High
#      Overlap: 2.37%
#   ❌ POT-T-655 — No intersection
#      Bounds: (-4139693.563874861, -603880.7830908563, -4132736.095700281, -599221.8261269907)
#      Min. distance to priority area: 13974.97 meters
#   ❌ POT-T-326 — No intersection
#      Bounds: (-4118821.159351122, -566617.9125050706, -4111863.691176542, -561961.4355230022)
#      Min. distance to priority area: 2782.99 meters
#   ✅ POT-T-354 — Intersection found
#      Bounds: (-4111863.691176542, -571274.6907220128, -4104906.223001963, -566617.9125050706)
#      Priority level(s): Extremely High
#      Overlap: 6.79%
#   ✅ POT-T-355 — Intersection found
#      Bounds: (-4104906.223001963, -571274.6907220128, -4097948.7548273834, -566617.9125050706)
#      Priority level(s): Extremely High
#      Overlap: 67.25%
#   ❌ POT-T-353 — No intersection
#      Bounds: (-4118821.159351122, -571274.6907220128, -4111863.691176542, -566617.9125050706)
#      Min. distance to priority area: 1487.66 meters
#   ✅ POT-T-393 — Intersection found
#      Bounds: (-4118821.159351122, -575931.7726758609, -4111863.691176542, -571274.6907220128)
#      Priority level(s): Extremely High
#      Overlap: 2.84%
#   ✅ S-M-1713 — Intersection found
#      Bounds: (-5148526.449188902, -3186080.23336501, -5120696.576490585, -3154740.8166665663)
#      Priority level(s): High, Very High
#      Overlap: 100.00%
#   ✅ S-M-1815 — Intersection found
#      Bounds: (-5204186.194585539, -3217490.9158222154, -5176356.321887221, -3186080.23336501)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ S-M-1910 — Intersection found
#      Bounds: (-5204186.194585539, -3248973.789650975, -5176356.321887221, -3217490.9158222154)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ S-M-1711 — Intersection found
#      Bounds: (-5176356.321887221, -3186080.23336501, -5148526.449188902, -3154740.8166665663)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ S-M-1817 — Intersection found
#      Bounds: (-5176356.321887221, -3217490.9158222154, -5148526.449188902, -3186080.23336501)
#      Priority level(s): High, Very High
#      Overlap: 100.00%
#   ✅ S-M-1599 — Intersection found
#      Bounds: (-5176356.321887221, -3154740.8166665663, -5148526.449188902, -3123471.749104577)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ S-M-1601 — Intersection found
#      Bounds: (-5148526.449188902, -3154740.8166665663, -5120696.576490585, -3123471.749104577)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ S-M-1908 — Intersection found
#      Bounds: (-5232016.067283858, -3248973.789650975, -5204186.194585539, -3217490.9158222154)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ❌ REC-T-191 — No intersection
#      Bounds: (-4299715.331890192, -1402665.1899679275, -4292757.863715612, -1397914.6444007552)
#      Min. distance to priority area: 9257.77 meters
#   ✅ TUC-T-154 — Intersection found
#      Bounds: (-4327545.20458851, -1303060.3497927347, -4313670.194766678, -1288857.1804959085)
#      Priority level(s): Extremely High
#      Overlap: 28.26%
#   ❌ TUC-T-161 — No intersection
#      Bounds: (-4327545.20458851, -1317269.89523635, -4313630.268239351, -1303060.3497927347)
#      Min. distance to priority area: 1325.90 meters
#   ❌ TUC-T-167 — No intersection
#      Bounds: (-4313630.268239351, -1331485.8902476795, -4299755.171508689, -1317269.89523635)
#      Min. distance to priority area: 14631.99 meters
#   ✅ TUC-T-146 — Intersection found
#      Bounds: (-4327545.20458851, -1288857.1804959085, -4313670.177260698, -1274660.3140843937)
#      Priority level(s): Extremely High
#      Overlap: 13.30%
#   ❌ SEAL-T-153 — No intersection
#      Bounds: (-4020584.0220292676, -1095348.1412394529, -4014496.179860892, -1090641.5572689108)
#      Min. distance to priority area: 13581.98 meters
#   ❌ SEAL-T-117 — No intersection
#      Bounds: (-4014459.1367324283, -1081230.1509776185, -4007501.6685578483, -1076525.3233882855)
#      Min. distance to priority area: 20652.85 meters
#   ❌ SEAL-T-179 — No intersection
#      Bounds: (-4014459.1367324283, -1104763.0840138483, -4007501.6685578483, -1100055.3159416579)
#      Min. distance to priority area: 5122.89 meters
#   ❌ SEAL-T-103 — No intersection
#      Bounds: (-3993586.732208689, -1071869.0107323315, -3986629.2640341097, -1067117.406162763)
#      Min. distance to priority area: 13999.90 meters
#   ❌ SEAL-M-503 — No intersection
#      Bounds: (-4007501.6685578483, -1288857.1804959085, -3979671.7958595306, -1260469.6774541626)
# ...
#   ✅ POT-M-391 — Intersection found
#      Bounds: (-4230140.650144396, -361982.5115784611, -4202310.777446077, -334111.1714019596)
#      Priority level(s): Very High
#      Overlap: 65.16%
#   ✅ POT-M-311 — Intersection found
#      Bounds: (-4202310.777446077, -334111.1714019596, -4174480.904747759, -306246.2039244224)
#      Priority level(s): Very High
#      Overlap: 56.59%
#   ✅ POT-M-395 — Intersection found
#      Bounds: (-4174480.904747759, -361982.5115784611, -4146651.0320494403, -334111.1714019596)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ POT-M-483 — Intersection found
#      Bounds: (-4118821.159351122, -389860.7582541958, -4090991.2866528034, -361982.5115784611)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ POT-M-671 — Intersection found
#      Bounds: (-4063161.413954485, -445640.10965602624, -4035331.5412561675, -417746.4458894469)
#      Priority level(s): Very High
#      Overlap: 51.40%
#   ✅ POT-M-393 — Intersection found
#      Bounds: (-4202310.777446077, -361982.5115784611, -4174480.904747759, -334111.1714019596)
#      Priority level(s): Very High
#      Overlap: 87.80%
#   ✅ POT-M-479 — Intersection found
#      Bounds: (-4174480.904747759, -389860.7582541958, -4146651.0320494403, -361982.5115784611)
#      Priority level(s): Very High
#      Overlap: 87.91%
#   ✅ POT-M-481 — Intersection found
#      Bounds: (-4146651.0320494403, -389860.7582541958, -4118821.159351122, -361982.5115784611)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ POT-M-573 — Intersection found
#      Bounds: (-4118821.159351122, -417746.4458894469, -4090991.2866528034, -389860.7582541958)
#      Priority level(s): Very High
#      Overlap: 77.86%
#   ✅ POT-M-575 — Intersection found
#      Bounds: (-4090991.2866528034, -417746.4458894469, -4063161.413954485, -389860.7582541958)
#      Priority level(s): Very High
#      Overlap: 99.93%
#   ✅ POT-M-673 — Intersection found
#      Bounds: (-4035331.5412561675, -445640.10965602624, -4007501.6685578483, -417746.4458894469)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ POT-M-473 — Intersection found
#      Bounds: (-4251013.054668135, -389860.7582541958, -4230140.650144396, -361982.5115784611)
#      Priority level(s): Extremely High
#      Overlap: 31.44%
#   ✅ POT-M-309 — Intersection found
#      Bounds: (-4230140.650144396, -334111.1714019596, -4202310.777446077, -306246.2039244224)
#      Priority level(s): Very High
#      Overlap: 100.00%
#   ✅ POT-M-389 — Intersection found
#      Bounds: (-4257970.522842714, -361982.5115784611, -4230140.650144396, -334111.1714019596)
#      Priority level(s): Very High
#      Overlap: 26.93%
#   ✅ POT-M-852 — Intersection found
#      Bounds: (-4132736.095700281, -482844.9950840397, -4118858.695612058, -473542.2854889546)
#      Priority level(s): Extremely High
#      Overlap: 73.49%
#   ✅ POT-M-569 — Intersection found
#      Bounds: (-4174480.904747759, -417746.4458894469, -4146651.0320494403, -389860.7582541958)
#      Priority level(s): Very High
#      Overlap: 29.98%
#   ✅ POT-M-477 — Intersection found
#      Bounds: (-4202310.777446077, -389860.7582541958, -4174480.904747759, -361982.5115784611)
#      Priority level(s): Very High
#      Overlap: 27.82%
#   ✅ PRC-T-117 — Intersection found
#      Bounds: (-6449572.997835287, -1574216.548161465, -6400870.72061323, -1516914.4453372387)
#      Priority level(s): High, Extremely High, Very High
#      Overlap: 71.49%
#   ✅ PRC-T-133 — Intersection found
#      Bounds: (-6456530.466009867, -1631643.4670073595, -6400870.72061323, -1574216.548161465)
#      Priority level(s): Extremely High, High, Very High
#      Overlap: 61.67%
#   ✅ PRC-T-147 — Intersection found
#      Bounds: (-6449572.997835287, -1689200.1396078935, -6400870.72061323, -1631643.4670073595)
#      Priority level(s): Extremely High, Very High, High
#      Overlap: 55.21%
#   ✅ PRC-T-101 — Intersection found
#      Bounds: (-6400870.72061323, -1516914.4453372387, -6345210.975216594, -1459732.2718804977)
#      Priority level(s): Very High, Extremely High
#      Overlap: 99.55%
#   ✅ PRC-T-118 — Intersection found
#      Bounds: (-6400870.72061323, -1574216.548161465, -6345210.975216594, -1516914.4453372387)
#      Priority level(s): Extremely High, Very High
#      Overlap: 76.16%
#   ✅ PRC-T-134 — Intersection found
#      Bounds: (-6400870.72061323, -1631643.4670073595, -6345210.975216594, -1574216.548161465)
#      Priority level(s): Extremely High, Very High
#      Overlap: 90.05%
#   ✅ PRC-T-84 — Intersection found
#      Bounds: (-6345210.975216594, -1459732.2718804977, -6289551.229819957, -1402665.1899679275)
#      Priority level(s): Very High
#      Overlap: 92.62%
#   ✅ PRC-T-102 — Intersection found
#      Bounds: (-6345210.975216594, -1516914.4453372387, -6289551.229819957, -1459732.2718804977)
#      Priority level(s): Very High
#      Overlap: 79.66%
#   ✅ PRC-T-119 — Intersection found
#      Bounds: (-6345210.975216594, -1574216.548161465, -6289551.229819957, -1516914.4453372387)
#      Priority level(s): Extremely High, Very High
#      Overlap: 34.27%
#   ✅ PRC-T-135 — Intersection found
#      Bounds: (-6345210.975216594, -1631643.4670073595, -6289551.229819957, -1574216.548161465)
#      Priority level(s): Extremely High, Very High
#      Overlap: 16.31%
#   ✅ PRC-T-85 — Intersection found
#      Bounds: (-6289551.229819957, -1459732.2718804977, -6233891.48442332, -1402665.1899679275)
#      Priority level(s): Very High, Extremely High
#      Overlap: 33.87%
#   ✅ PRC-T-103 — Intersection found
#      Bounds: (-6289551.229819957, -1516914.4453372387, -6233891.48442332, -1459732.2718804977)
#      Priority level(s): Very High
#      Overlap: 13.07%
#   ✅ PRC-T-120 — Intersection found
#      Bounds: (-6289551.229819957, -1574216.548161465, -6233891.48442332, -1516914.4453372387)
#      Priority level(s): Very High
#      Overlap: 32.61%
#   ✅ PRC-T-104 — Intersection found
#      Bounds: (-6233891.48442332, -1516914.4453372387, -6185189.207201262, -1459732.2718804977)
#      Priority level(s): Extremely High
#      Overlap: 17.79%
#   ✅ PRC-T-121 — Intersection found
#      Bounds: (-6233891.48442332, -1574216.548161465, -6178231.739026683, -1516914.4453372387)
#      Priority level(s): Very High, Extremely High
#      Overlap: 2.48%
#   ✅ PRC-T-105 — Intersection found
#      Bounds: (-6178231.739026683, -1526456.3360261659, -6122571.993630046, -1459732.2718804977)
#      Priority level(s): Very High, High, Extremely High
#      Overlap: 54.10%
#   ✅ PRC-T-122 — Intersection found
#      Bounds: (-6178231.739026683, -1574216.548161465, -6122571.993630046, -1521684.9728669897)
#      Priority level(s): Extremely High
#      Overlap: 56.64%
#   ✅ PRC-T-106 — Intersection found
#      Bounds: (-6122571.993630046, -1516914.4453372387, -6066912.24823341, -1459732.2718804977)
#      Priority level(s): High, Very High
#      Overlap: 34.51%
#   ✅ PRC-T-123 — Intersection found
#      Bounds: (-6122571.993630046, -1574216.548161465, -6066912.24823341, -1516914.4453372387)
#      Priority level(s): High, Very High, Extremely High
#      Overlap: 62.97%
#   ✅ PRC-T-100 — Intersection found
#      Bounds: (-6463487.934184447, -1516914.4453372387, -6400870.72061323, -1464492.990733102)
#      Priority level(s): Extremely High, Very High
#      Overlap: 48.13%
#   ✅ PRC-T-54 — Intersection found
#      Bounds: (-6846148.683786325, -1402665.1899679275, -6734829.192993051, -1293590.8663263351)
#      Priority level(s): Extremely High, High, Very High
#      Overlap: 47.05%
#   ✅ TUC-T-112 — Intersection found
#      Bounds: (-4285800.395541033, -1217934.417530921, -4271885.459191873, -1203767.9720651004)
#      Priority level(s): Very High
#      Overlap: 32.62%
#   ✅ TUC-T-113 — Intersection found
#      Bounds: (-4271885.459191873, -1217934.417530921, -4257970.522842714, -1203767.9720651004)
#      Priority level(s): Very High
#      Overlap: 14.38%
#   ❌ TUC-T-114 — No intersection
#      Bounds: (-4257970.522842714, -1217934.417530921, -4244055.5864935545, -1203767.9720651004)
#      Min. distance to priority area: 3525.12 meters
#   ✅ TUC-T-115 — Intersection found
#      Bounds: (-4341460.140937669, -1232106.8018967598, -4327545.20458851, -1217934.417530921)
#      Priority level(s): High
#      Overlap: 39.65%
#   ✅ TUC-T-116 — Intersection found
#      Bounds: (-4327545.20458851, -1232106.8018967598, -4313630.268239351, -1217934.417530921)
#      Priority level(s): Very High
#      Overlap: 32.64%
#   ✅ TUC-T-119 — Intersection found
#      Bounds: (-4285800.395541033, -1232106.8018967598, -4271885.459191873, -1217934.417530921)
#      Priority level(s): Very High
#      Overlap: 59.47%
#   ✅ TUC-T-120 — Intersection found
#      Bounds: (-4271885.459191873, -1232106.8018967598, -4257970.522842714, -1217934.417530921)
#      Priority level(s): Very High
#      Overlap: 78.45%
#   ✅ TUC-T-121 — Intersection found
#      Bounds: (-4257970.522842714, -1232106.8018967598, -4244055.5864935545, -1217934.417530921)
#      Priority level(s): Very High
#      Overlap: 17.17%
#   ✅ TUC-T-126 — Intersection found
#      Bounds: (-4285800.395541033, -1246285.1976566475, -4271885.459191873, -1232106.8018967598)
#      Priority level(s): Very High
#      Overlap: 82.16%
#   ✅ TUC-T-127 — Intersection found
#      Bounds: (-4271885.459191873, -1246285.1976566475, -4257970.522842714, -1232106.8018967598)
#      Priority level(s): Very High
#      Overlap: 99.58%
#   ✅ TUC-T-128 — Intersection found
#      Bounds: (-4257970.522842714, -1246285.1976566475, -4244055.5864935545, -1232106.8018967598)
#      Priority level(s): Very High
#      Overlap: 82.65%
#   ✅ TUC-T-134 — Intersection found
#      Bounds: (-4271885.459191873, -1260469.6774541626, -4257970.522842714, -1246285.1976566475)
#      Priority level(s): Very High
#      Overlap: 71.08%
#   ✅ TUC-T-135 — Intersection found
#      Bounds: (-4257970.522842714, -1260469.6774541626, -4244055.5864935545, -1246285.1976566475)
#      Priority level(s): Very High
#      Overlap: 81.04%
#   ✅ TUC-T-136 — Intersection found
#      Bounds: (-4244055.5864935545, -1260469.6774541626, -4230140.650144396, -1241558.3933229398)
#      Priority level(s): Very High
#      Overlap: 2.52%
#   ✅ TUC-T-143 — Intersection found
#      Bounds: (-4257970.522842714, -1274660.3140843937, -4244055.5864935545, -1260469.6774541626)
#      Priority level(s): Very High
#      Overlap: 5.12%
#   ✅ TUC-T-144 — Intersection found
#      Bounds: (-4244055.5864935545, -1274660.3140843937, -4230140.650144396, -1260469.6774541626)
#      Priority level(s): Very High
#      Overlap: 0.41%
#   ✅ TUC-T-91 — Intersection found
#      Bounds: (-4341460.140937669, -1189607.3931528635, -4327545.20458851, -1175452.6085934301)
#      Priority level(s): High
#      Overlap: 0.14%
#   ✅ TUC-T-108 — Intersection found
#      Bounds: (-4341460.140937669, -1217934.417530921, -4327545.20458851, -1203767.9720651004)
#      Priority level(s): High
#      Overlap: 11.72%
#   ✅ TUC-T-109 — Intersection found
#      Bounds: (-4327545.20458851, -1217934.417530921, -4313630.268239351, -1203767.9720651004)
#      Priority level(s): Very High
#      Overlap: 9.16%
#   ✅ TUC-T-110 — Intersection found
#      Bounds: (-4313630.268239351, -1232106.8018967598, -4299715.331890192, -1208489.4651447725)
#      Priority level(s): Very High
#      Overlap: 84.62%
#   ✅ TUC-T-111 — Intersection found
#      Bounds: (-4299715.331890192, -1232106.8018967598, -4285800.395541033, -1208489.4651447725)
#      Priority level(s): Very High
#      Overlap: 20.56%
#   ✅ TUC-T-100 — Intersection found
#      Bounds: (-4341460.140937669, -1203767.9720651004, -4327545.20458851, -1189607.3931528635)
#      Priority level(s): High
#      Overlap: 0.11%
#   ❌ PAR-T-344 — No intersection
#      Bounds: (-5739911.244028168, -3154740.8166665663, -5684251.498631531, -3061141.038886033)
#      Min. distance to priority area: 231758.14 meters
#   ✅ S-M-1825 — Intersection found
#      Bounds: (-5065036.831093947, -3217490.9158222154, -5037206.958395629, -3186080.23336501)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ S-M-1920 — Intersection found
#      Bounds: (-5065036.831093947, -3248973.789650975, -5037206.958395629, -3217490.9158222154)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ S-M-1607 — Intersection found
#      Bounds: (-5065036.831093947, -3154740.8166665663, -5037206.958395629, -3123471.749104577)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ S-M-1609 — Intersection found
#      Bounds: (-5037206.958395629, -3154740.8166665663, -5009377.085697311, -3123471.749104577)
#      Priority level(s): High
#      Overlap: 100.00%
#   ✅ S-M-1605 — Intersection found
#      Bounds: (-5092866.703792266, -3154740.8166665663, -5065036.831093947, -3123471.749104577)
#      Priority level(s): High, Very High
#      Overlap: 100.00%
#   ✅ S-M-1613 — Intersection found
#      Bounds: (-4981547.212998993, -3154740.8166665663, -4925887.467602355, -3123471.749104577)
#      Priority level(s): High
#      Overlap: 97.30%
#   ✅ S-M-1617 — Intersection found
#      Bounds: (-4925887.467602355, -3186080.23336501, -4870227.722205719, -3123471.749104577)
#      Priority level(s): High
#      Overlap: 21.86%
#   ❌ C-M-69 — No intersection
#      Bounds: (-4341460.140937669, -2451599.087377855, -4313630.268239351, -2421713.5040392564)
#      Min. distance to priority area: 36458.83 meters
#   ❌ C-M-109 — No intersection
#      Bounds: (-4341460.140937669, -2481536.081273684, -4313630.268239351, -2451599.087377855)
#      Min. distance to priority area: 56291.78 meters
#   ❌ C-M-157 — No intersection
#      Bounds: (-4350736.765170442, -2511525.2348457123, -4313630.268239351, -2481536.081273684)
#      Min. distance to priority area: 82290.71 meters
#   ❌ C-M-212 — No intersection
#      Bounds: (-4341460.140937669, -2541567.3031267496, -4313630.268239351, -2511525.2348457123)
#      Min. distance to priority area: 87750.41 meters
#   ❌ C-M-279 — No intersection
#      Bounds: (-4341460.140937669, -2571663.0471736453, -4313630.268239351, -2541567.3031267496)
#      Min. distance to priority area: 87834.97 meters
#   ❌ C-M-348 — No intersection
#      Bounds: (-4341460.140937669, -2601813.2341792854, -4313630.268239351, -2571663.0471736453)
#      Min. distance to priority area: 79456.16 meters
#   ❌ C-M-415 — No intersection
#      Bounds: (-4341460.140937669, -2632018.6375864246, -4313630.268239351, -2601813.2341792854)
#      Min. distance to priority area: 52374.52 meters
#   ❌ C-M-483 — No intersection
#      Bounds: (-4341460.140937669, -2662280.0372034023, -4313630.268239351, -2632018.6375864246)
#      Min. distance to priority area: 25360.04 meters
#   ❌ C-M-549 — No intersection
#      Bounds: (-4341460.140937669, -2692598.2193217897, -4313630.268239351, -2662280.0372034023)
#      Min. distance to priority area: 8548.74 meters
#   ❌ C-M-350 — No intersection
#      Bounds: (-4313630.268239351, -2601813.2341792854, -4285800.395541033, -2571663.0471736453)
#      Min. distance to priority area: 81199.28 meters
#   ❌ C-M-417 — No intersection
#      Bounds: (-4313630.268239351, -2632018.6375864246, -4285800.395541033, -2601813.2341792854)
#      Min. distance to priority area: 66243.14 meters
#   ❌ C-M-485 — No intersection
#      Bounds: (-4313630.268239351, -2662280.0372034023, -4285800.395541033, -2632018.6375864246)
#      Min. distance to priority area: 46499.60 meters
#   ❌ C-M-13 — No intersection
#      Bounds: (-4424949.759032625, -2391878.5879443143, -4397119.886334306, -2362093.601478114)
#      Min. distance to priority area: 43840.39 meters
#   ❌ C-M-107 — No intersection
#      Bounds: (-4371029.380679633, -2481536.081273684, -4341460.140937669, -2451599.087377855)
#      Min. distance to priority area: 76224.45 meters
#   ❌ C-M-481 — No intersection
#      Bounds: (-4369290.013635987, -2662280.0372034023, -4341460.140937669, -2632018.6375864246)
#      Min. distance to priority area: 13746.94 meters
#
# 🟩 Processing: port
#   ✅ Feature 0 — Intersection found
#      Bounds: (-5398747.840245735, -111325.1428663851, -5398747.840245735, -111325.1428663851)
#      Priority level(s): Extremely High
#      Overlap: 0.00%
#
# 🟩 Processing: airport
#   ❌ Feature 0 — No intersection
#      Bounds: (-5765916.701591876, 430173.61806823517, -5765916.701591876, 430173.61806823517)
#      Min. distance to priority area: 2274.80 meters
#
# 📤 Exporting results to Excel (in kilometers)...
# ✅ All diagnostics completed and exported.

# %% [markdown]
# Robustness check

# %%
import folium
import geopandas as gpd

# Step 1: Create base map
m = folium.Map(location=[-10, -55], zoom_start=4, tiles="CartoDB Positron")

# Step 2: Reproject all layers to EPSG:4326 for Folium display
priority_display = all_priority_areas.to_crs(epsg=4326)
exploration_display = exploration_blocks.to_crs(epsg=4326)
offered_display = offered_blocks.to_crs(epsg=4326)
port_display = port.to_crs(epsg=4326)
airport_display = airport.to_crs(epsg=4326)

# Step 3: Add base layers
folium.GeoJson(priority_display, name="Priority Areas",
               style_function=lambda x: {"color": "gray", "weight": 1, "fillOpacity": 0.3}).add_to(m)
folium.GeoJson(exploration_display, name="Exploration Blocks",
               style_function=lambda x: {"color": "red", "weight": 2}).add_to(m)
folium.GeoJson(offered_display, name="Offered Blocks",
               style_function=lambda x: {"color": "black", "weight": 2}).add_to(m)
folium.GeoJson(port_display, name="Port",
               style_function=lambda x: {"color": "blue", "weight": 4}).add_to(m)
folium.GeoJson(airport_display, name="Airport",
               style_function=lambda x: {"color": "green", "weight": 4}).add_to(m)

# Step 4: Helper function to plot green buffers from 'priority_dist'
def plot_green_buffer(gdf, label):
    if "priority_dist" not in gdf.columns:
        print(f"⚠️ Skipping {label}: 'priority_dist' column not found.")
        return
    gdf = gdf[gdf["priority_dist"].notna()].copy()
    if gdf.empty:
        print(f"⚠️ No valid distances in {label}.")
        return
    gdf_buffer = gdf.copy()
    gdf_buffer["buffer_geom"] = gdf_buffer.apply(
        lambda row: row.geometry.buffer(row["priority_dist"] * 1000), axis=1  # km to meters
    )
    gdf_buffer = gpd.GeoDataFrame(
        gdf_buffer.drop(columns="geometry"),
        geometry="buffer_geom",
        crs=gdf.crs
    ).to_crs(epsg=4326)

    folium.GeoJson(
        gdf_buffer,
        name=f"{label} Buffer",
        style_function=lambda x: {"color": "green", "weight": 1, "fillOpacity": 0.15}
    ).add_to(m)

# Step 5: Plot all green buffers
plot_green_buffer(exploration_blocks, "Exploration")
plot_green_buffer(offered_blocks, "Offered")
plot_green_buffer(port, "Port")
plot_green_buffer(airport, "Airport")

# Step 6: Layer control and display
folium.LayerControl(collapsed=False).add_to(m)

# Step 7: Display map
m

# %% [markdown]
# Statistics

# %%
# Normalize helper
def normalize(text):
    return text.lower().replace("_", " ").strip()

# ----- Offered Blocks -----
foz_offered = offered_blocks[offered_blocks["nome_bacia"].apply(normalize) == "foz do amazonas"]
total_offered = len(foz_offered)
intersecting_offered = foz_offered[foz_offered["priority_class"] != "No Priority Area"]
count_offered = len(intersecting_offered)
percent_offered = (count_offered / total_offered) * 100 if total_offered > 0 else 0

print("📊 Offered Blocks — Foz do Amazonas")
print(f"- Total: {total_offered}")
print(f"- With intersection: {count_offered}")
print(f"- % Intersecting: {percent_offered:.2f}%")

print("\n🔹 Detailed List of Offered Blocks:")
for _, row in foz_offered.iterrows():
    bloco = row["nomenclatu"]
    if row["priority_class"] != "No Priority Area":
        print(f"  ✅ {bloco} — intersects ({row['priority_class']})")
    else:
        print(f"  ❌ {bloco} — no intersection, dist = {row['priority_dist']:.2f} km")

# ----- Exploration Blocks -----
foz_exploration = exploration_blocks[exploration_blocks["NOM_BACIA"].apply(normalize) == "foz do amazonas"]
total_exploration = len(foz_exploration)
intersecting_exploration = foz_exploration[foz_exploration["priority_class"] != "No Priority Area"]
count_exploration = len(intersecting_exploration)
percent_exploration = (count_exploration / total_exploration) * 100 if total_exploration > 0 else 0

print("\n📊 Exploration Blocks — Foz do Amazonas")
print(f"- Total: {total_exploration}")
print(f"- With intersection: {count_exploration}")
print(f"- % Intersecting: {percent_exploration:.2f}%")

print("\n🔹 Detailed List of Exploration Blocks:")
for _, row in foz_exploration.iterrows():
    bloco = row["COD_BLOCO"]
    if row["priority_class"] != "No Priority Area":
        print(f"  ✅ {bloco} — intersects ({row['priority_class']})")
    else:
        print(f"  ❌ {bloco} — no intersection, dist = {row['priority_dist']:.2f} km")
# Out:
# 📊 Offered Blocks — Foz do Amazonas
# - Total: 47
# - With intersection: 27
# - % Intersecting: 57.45%
#
# 🔹 Detailed List of Offered Blocks:
#   ✅ FZA-M-545 — intersects (Extremely High)
#   ✅ FZA-M-617 — intersects (Extremely High)
#   ✅ FZA-M-407 — intersects (Extremely High)
#   ✅ FZA-M-475 — intersects (Extremely High)
#   ✅ FZA-M-547 — intersects (Extremely High)
#   ❌ FZA-M-619 — no intersection, dist = 8.39 km
#   ❌ FZA-M-690 — no intersection, dist = 9.45 km
#   ✅ FZA-M-409 — intersects (Extremely High)
#   ✅ FZA-M-477 — intersects (Extremely High)
#   ✅ FZA-M-1102 — intersects (Extremely High)
#   ✅ FZA-M-184 — intersects (Extremely High)
#   ❌ FZA-M-255 — no intersection, dist = 3.19 km
#   ❌ FZA-M-261 — no intersection, dist = 23.39 km
#   ❌ FZA-M-328 — no intersection, dist = 0.30 km
#   ❌ FZA-M-263 — no intersection, dist = 18.98 km
#   ✅ FZA-M-330 — intersects (Extremely High)
#   ❌ FZA-M-265 — no intersection, dist = 18.43 km
#   ✅ FZA-M-332 — intersects (Extremely High)
#   ❌ FZA-M-267 — no intersection, dist = 20.04 km
#   ✅ FZA-M-334 — intersects (Extremely High)
#   ✅ FZA-M-399 — intersects (Extremely High)
#   ✅ FZA-M-401 — intersects (Extremely High)
#   ✅ FZA-M-403 — intersects (Extremely High)
#   ✅ FZA-M-1410 — intersects (Extremely High)
#   ✅ FZA-M-541 — intersects (Extremely High)
#   ✅ FZA-M-759 — intersects (Extremely High)
#   ✅ FZA-M-549 — intersects (Extremely High)
#   ❌ FZA-M-621 — no intersection, dist = 9.05 km
#   ❌ FZA-M-692 — no intersection, dist = 23.38 km
#   ❌ FZA-M-761 — no intersection, dist = 7.82 km
#   ✅ FZA-M-338 — intersects (Extremely High)
#   ✅ FZA-M-543 — intersects (Extremely High)
#   ❌ FZA-M-188 — no intersection, dist = 36.71 km
#   ❌ FZA-M-190 — no intersection, dist = 42.68 km
#   ❌ FZA-M-192 — no intersection, dist = 48.94 km
#   ❌ FZA-M-194 — no intersection, dist = 46.89 km
#   ❌ FZA-M-196 — no intersection, dist = 46.35 km
#   ✅ FZA-M-336 — intersects (Extremely High)
#   ✅ FZA-M-469 — intersects (Extremely High)
#   ✅ FZA-M-471 — intersects (Extremely High)
#   ✅ FZA-M-405 — intersects (Extremely High)
#   ✅ FZA-M-473 — intersects (Extremely High)
#   ❌ FZA-M-1040 — no intersection, dist = 14.18 km
#   ❌ FZA-M-1042 — no intersection, dist = 32.07 km
#   ✅ FZA-M-326 — intersects (Extremely High)
#   ❌ FZA-M-257 — no intersection, dist = 10.73 km
#   ❌ FZA-M-259 — no intersection, dist = 18.04 km
#
# 📊 Exploration Blocks — Foz do Amazonas
# - Total: 9
# - With intersection: 3
# - % Intersecting: 33.33%
#
# 🔹 Detailed List of Exploration Blocks:
#   ❌ FZA-M-57 — no intersection, dist = 17.88 km
#   ❌ FZA-M-88 — no intersection, dist = 20.09 km
#   ✅ FZA-M-539 — intersects (Extremely High)
#   ❌ FZA-M-90 — no intersection, dist = 33.96 km
#   ❌ FZA-M-254 — no intersection, dist = 0.69 km
#   ❌ FZA-M-127 — no intersection, dist = 15.06 km
#   ✅ FZA-M-125 — intersects (Extremely High)
#   ✅ FZA-M-86 — intersects (Extremely High)
#   ❌ FZA-M-59 — no intersection, dist = 37.40 km
